# %% [markdown]
# ### Notebook for Extracting Contracts Related to Artificial Intelligence, Machine Learning, and Deep Learning

# %%
# Importing necessary libraries for data manipulation, visualization, and text processing
import pandas as pd
import os
from nltk.tokenize import word_tokenize
from string import punctuation
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
from collections import Counter
from bertopic import BERTopic
from transformers import AutoTokenizer, AutoModel
from sentence_transformers import SentenceTransformer, models
import matplotlib.pyplot as plt
import warnings

# Ignoring deprecation warnings that might clutter the notebook
warnings.filterwarnings("ignore", category=DeprecationWarning)

# Configuring matplotlib to display visuals inline in a Jupyter notebook
# %matplotlib inline

# Adjusting Pandas display settings to show unlimited rows and columns with increased column width
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 200)

# # Downloading NLTK packages necessary for tokenization, stopwords, and lemmatization
import nltk
nltk.download('punkt')     # Tokenizer to split text into words
nltk.download('stopwords') # Common words ('the', 'a', etc.) that usually do not carry much meaning
nltk.download('wordnet')   # Lexical database for the English language, helps in lemmatization
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sankar.kalaga\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sankar.kalaga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sankar.kalaga\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Importing the dataset of contract opportunities from a CSV file
samgov_data = pd.read_csv("ContractOpportunitiesFullCSV.csv", encoding="ansi", dtype="string")

# Filtering the dataset to include only the columns that are relevant for analysis
samgov_data = samgov_data[['Title', 'Sol#', 'Department/Ind.Agency', 'AwardNumber', 'AwardDate', 'PostedDate', 'Award$', 'Awardee', 'Link', 'Description']]

# Removing rows where the 'Department/Ind.Agency' column is missing to ensure data completeness
samgov_data = samgov_data.dropna(subset=['Department/Ind.Agency'])

# Printing the number of rows in the dataset after cleaning to understand the scope of data
print(samgov_data.shape[0])

# Displaying the first few rows of the dataset to get a preview of the data
samgov_data.head()
# Out:
# 74040
#                                                                             Title  \
# 0                                               North Field ALCS Computer Upgrade
# 1                                                 Zeiss LSM980 Microscope Upgrade
# 2                                               Maestro Pro Assay System Purchase
# 3  Maui Wildfire Temporary Debris Storage Operations & Residential Debris Removal
# 4  Maui Wildfire Temporary Debris Storage Operations & Residential Debris Removal
#
#              Sol#                     Department/Ind.Agency AwardNumber  \
# 0  F1M3E34003AQ02                           DEPT OF DEFENSE        <NA>
# 1  75N95024Q00305  HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>
# 2  75N95024Q00304  HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>
# 3   W9128A24R0027                           DEPT OF DEFENSE        <NA>
# 4   W9128A24R0027                           DEPT OF DEFENSE        <NA>
#
#   AwardDate                  PostedDate Award$ Awardee  \
# 0      <NA>  2024-05-21 23:28:08.079-04   <NA>    <NA>
# 1      <NA>  2024-05-21 23:03:00.374-04   <NA>    <NA>
# 2      <NA>  2024-05-21 22:59:18.743-04   <NA>    <NA>
# 3      <NA>   2024-05-21 22:53:01.18-04   <NA>    <NA>
# 4      <NA>  2024-05-21 22:51:27.869-04   <NA>    <NA>
#
#                                                         Link  \
# 0  https://sam.gov/opp/d606819a57d0473b9110047867eadf16/view
# 1  https://sam.gov/opp/5417ce1082b84ea182c41aa3631aee5b/view
# 2  https://sam.gov/opp/754bb52525fe47ec981a96f85e02b2a2/view
# 3  https://sam.gov/opp/da6189fb140344f199736f6df314c968/view
# 4  https://sam.gov/opp/b9ac402b52f247d58294c95274c97b4b/view
#
#                                                                                                                                                                                                Description
# 0  THIS IS NOT A REQUEST FOR COMPETITIVE PROPOSALS. This is a notice of intent to award a sole source contract under statutory authority 10 USC 2304(c)(1), set forth in Federal Acquisition Regulation...
# 1  SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00305 Title:  Zeiss LSM980 Microscope Upgrade Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Instru...
# 2  SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00304 Title:  Maestro Pro Assay System Purchase Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Inst...
# 3  This is a special notice per Federal Acquisition Regulation (FAR) 5.2 – Synopses of Proposed Contract Action. The U.S. Army Corps of Engineers (USACE), Honolulu District (POH), intends to issue a ...
# 4  This is a special notice per Federal Acquisition Regulation (FAR) 5.2 – Synopses of Proposed Contract Action. The U.S. Army Corps of Engineers (USACE), Honolulu District (POH), intends to issue a ...

# %%
# Setting the start date for filtering the dataset
start_date = '2017-12-31'

# Cleaning the 'AwardDate' by removing the time part and converting it to a date format
samgov_data['AwardDate'] = samgov_data['AwardDate'].str.replace("T00:00:00", '')
samgov_data['AwardDate'] = pd.to_datetime(samgov_data['AwardDate'], errors='coerce', format='%Y-%m-%d')

# Cleaning 'PostedDate' by isolating the date part and converting it to a date format
samgov_data['PostedDate'] = samgov_data['PostedDate'].str.split(" ").str[0]
samgov_data['PostedDate'] = pd.to_datetime(samgov_data['PostedDate'], errors='coerce')

# Creating a mask to filter rows where 'AwardDate' or 'PostedDate' is greater than the start date
time_mask = (samgov_data['AwardDate'] > start_date) | (samgov_data['PostedDate'] > start_date)

# Applying the mask to the DataFrame to filter relevant data
samgov_data_5yrs = samgov_data[time_mask]

# Printing the number of rows in the filtered dataset to check the amount of data
print(samgov_data_5yrs.shape[0])

# Displaying the first few rows of the filtered dataset for a quick preview
samgov_data_5yrs.head()
# Out:
# 72563
#                                                                             Title  \
# 0                                               North Field ALCS Computer Upgrade
# 1                                                 Zeiss LSM980 Microscope Upgrade
# 2                                               Maestro Pro Assay System Purchase
# 3  Maui Wildfire Temporary Debris Storage Operations & Residential Debris Removal
# 4  Maui Wildfire Temporary Debris Storage Operations & Residential Debris Removal
#
#              Sol#                     Department/Ind.Agency AwardNumber  \
# 0  F1M3E34003AQ02                           DEPT OF DEFENSE        <NA>
# 1  75N95024Q00305  HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>
# 2  75N95024Q00304  HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>
# 3   W9128A24R0027                           DEPT OF DEFENSE        <NA>
# 4   W9128A24R0027                           DEPT OF DEFENSE        <NA>
#
#   AwardDate PostedDate Award$ Awardee  \
# 0       NaT 2024-05-21   <NA>    <NA>
# 1       NaT 2024-05-21   <NA>    <NA>
# 2       NaT 2024-05-21   <NA>    <NA>
# 3       NaT 2024-05-21   <NA>    <NA>
# 4       NaT 2024-05-21   <NA>    <NA>
#
#                                                         Link  \
# 0  https://sam.gov/opp/d606819a57d0473b9110047867eadf16/view
# 1  https://sam.gov/opp/5417ce1082b84ea182c41aa3631aee5b/view
# 2  https://sam.gov/opp/754bb52525fe47ec981a96f85e02b2a2/view
# 3  https://sam.gov/opp/da6189fb140344f199736f6df314c968/view
# 4  https://sam.gov/opp/b9ac402b52f247d58294c95274c97b4b/view
#
#                                                                                                                                                                                                Description
# 0  THIS IS NOT A REQUEST FOR COMPETITIVE PROPOSALS. This is a notice of intent to award a sole source contract under statutory authority 10 USC 2304(c)(1), set forth in Federal Acquisition Regulation...
# 1  SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00305 Title:  Zeiss LSM980 Microscope Upgrade Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Instru...
# 2  SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00304 Title:  Maestro Pro Assay System Purchase Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Inst...
# 3  This is a special notice per Federal Acquisition Regulation (FAR) 5.2 – Synopses of Proposed Contract Action. The U.S. Army Corps of Engineers (USACE), Honolulu District (POH), intends to issue a ...
# 4  This is a special notice per Federal Acquisition Regulation (FAR) 5.2 – Synopses of Proposed Contract Action. The U.S. Army Corps of Engineers (USACE), Honolulu District (POH), intends to issue a ...

# %%
# Creating a set of unique department or agency names from the 'Department/Ind.Agency' column of the filtered dataset
set(samgov_data_5yrs['Department/Ind.Agency'].to_dict().values())
# Out:
# {'ADMINISTRATIVE OFFICE OF THE US COURTS',
#  'AGENCY FOR INTERNATIONAL DEVELOPMENT',
#  'AGRICULTURE, DEPARTMENT OF',
#  'ARCHITECT OF THE CAPITOL',
#  'CHEMICAL SAFETY AND HAZARD INVESTIGATION BOARD',
#  'COMMERCE, DEPARTMENT OF',
#  'COMMODITY FUTURES TRADING COMMISSION',
#  'CONSUMER FINANCIAL PROTECTION BUREAU',
#  'CORPORATION FOR NATIONAL AND COMMUNITY SERVICE',
#  'COURT SERVICES AND OFFENDER SUPERVISION AGENCY',
#  'DEPT OF DEFENSE',
#  'DISTRICT OF COLUMBIA COURTS',
#  'EDUCATION, DEPARTMENT OF',
#  'ENERGY, DEPARTMENT OF',
#  'ENVIRONMENTAL PROTECTION AGENCY',
#  'EXPORT-IMPORT BANK OF THE US',
#  'FEDERAL COMMUNICATIONS COMMISSION',
#  'FEDERAL DEPOSIT INSURANCE CORPORATION',
#  'FEDERAL HOUSING FINANCE AGENCY',
#  'FEDERAL MEDIATION AND CONCILIATION SERVICE',
#  'FEDERAL TRADE COMMISSION',
#  'GENERAL SERVICES ADMINISTRATION',
#  'GOVERNMENT ACCOUNTABILITY OFFICE',
#  'HEALTH AND HUMAN SERVICES, DEPARTMENT OF',
#  'HOMELAND SECURITY, DEPARTMENT OF',
#  'HOUSE OF REPRESENTATIVES, THE',
#  'HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF',
#  'INTERIOR, DEPARTMENT OF THE',
#  'INTERNATIONAL BOUNDARY AND WATER COMMISSION: US-MEXICO',
#  'INTERNATIONAL TRADE COMMISSION, UNITED STATES (DUNS # 02-1877998)',
#  'J F KENNEDY CENTER FOR THE PERFORMING ARTS',
#  'JUSTICE, DEPARTMENT OF',
#  'LABOR, DEPARTMENT OF',
#  'LIBRARY OF CONGRESS',
#  'MERIT SYSTEMS PROTECTION BOARD',
#  'MILLENNIUM CHALLENGE CORPORATION',
#  'NATIONAL AERONAUTICS AND SPACE ADMINISTRATION',
#  'NATIONAL ARCHIVES AND RECORDS ADMINISTRATION',
#  'NATIONAL GALLERY OF ART',
#  'NATIONAL SCIENCE FOUNDATION',
#  'NATIONAL TRANSPORTATION SAFETY BOARD',
#  'NUCLEAR REGULATORY COMMISSION',
#  'OFFICE OF PERSONNEL MANAGEMENT',
#  'OFFICE OF THE DIRECTOR OF NATIONAL INTELLIGENCE',
#  'OPEN WORLD LEADERSHIP CENTER',
#  'PEACE CORPS',
#  'PENSION BENEFIT GUARANTY CORPORATION',
#  'POSTAL SERVICE',
#  'SECURITIES AND EXCHANGE COMMISSION',
#  'SELECTIVE SERVICE SYSTEM',
#  'SENATE, THE',
#  'SMALL BUSINESS ADMINISTRATION',
#  'SMITHSONIAN INSTITUTION',
#  'SOCIAL SECURITY ADMINISTRATION',
#  'STATE, DEPARTMENT OF',
#  'THE LEGISLATIVE BRANCH',
#  'TRANSPORTATION, DEPARTMENT OF',
#  'TREASURY, DEPARTMENT OF THE',
#  'UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG',
#  'UNITED STATES GOVERNMENT PUBLISHING OFFICE',
#  'UNITED STATES HOLOCAUST MEMORIAL MUSEUM',
#  'UNITED STATES INTERNATIONAL DEVELOPMENT FINANCE CORPORATION',
#  'UNITED STATES TRADE AND DEVELOPMENT AGENCY',
#  'VETERANS AFFAIRS, DEPARTMENT OF'}

# %%
# Define a list of departments to be excluded from the dataset
exclude_departments = ["DEPT OF DEFENSE",
    "HOMELAND SECURITY, DEPARTMENT OF",
    "OFFICE OF THE DIRECTOR OF NATIONAL INTELLIGENCE"]
# Filter out rows where 'Department/Ind.Agency' is in the list of departments to exclude
samgov_data_5yrs = samgov_data_5yrs[~samgov_data_5yrs["Department/Ind.Agency"].isin(exclude_departments)]
# Print the number of rows in the dataset after excluding specified departments
print('Number of the contracts excluding the departments:',samgov_data_5yrs.shape[0])
# Out:
# Number of the contracts excluding the departments: 26236

# %%
# Convert 'Description' and 'Title' columns to string to ensure data consistency
samgov_data_5yrs['Description']=samgov_data_5yrs['Description'].astype(str)
samgov_data_5yrs['Title']=samgov_data_5yrs['Title'].astype(str)
# Combine 'Description' and 'Title' into a new column 'Title_Desc'
samgov_data_5yrs['Title_Desc'] = samgov_data_5yrs['Description'] + ' ' + samgov_data_5yrs['Title']
# Remove the string "nan" from 'Title_Desc' which appears due to conversion of NaN values to string
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("nan", "")
# Convert the entire 'Title_Desc' column to lowercase to standardize the text
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.lower()
# Replace various highly repeated words and characters to clean and normalize the text
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("-", " ") # Replacing hyphens with spaces for consistency
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("award", "")  # Removing the word 'award'
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("multiple", " ") # Removing the word 'multiple'
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("schedule", " ") # Removing the word 'schedule'
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("national", " ") # Removing the word 'national'
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("notice", " ") # Removing the word 'notice
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("fy24", "") # Removing the string 'fy24'
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("menu", "") # Removing the word 'menu'
samgov_data_5yrs['Title_Desc']=samgov_data_5yrs['Title_Desc'].str.replace("item", "") # Removing the word 'item'

# %%
# Text Preprocessing for Title and Description Columns
# Remove punctuation from abstracts
Title_Desc_no_punc = [''.join(c for c in wordP if c not in punctuation) for wordP in samgov_data_5yrs.Title_Desc]
Title_Desc_no_punc
tokenized_Title_Description = [word_tokenize(wordT) for wordT in Title_Desc_no_punc]

# Get English stopwords
sw = stopwords.words('english')

# Remove stopwords from each title
DescTitle_no_sw = [' '.join([w for w in description_tokens if w.lower() not in sw]) for description_tokens in tokenized_Title_Description]

# Stemmer (reducing words to their root form and simplifying keyword usage)
stemmer = PorterStemmer()
desctitle_stemmed = [' '.join([stemmer.stem(word) for word in text.split()]) for text in DescTitle_no_sw]

#Lemmatizer (preserves semantic meaning by converting words to their base forms)
lemmatizer = WordNetLemmatizer()
desctitle_lemmatized = [' '.join([lemmatizer.lemmatize(word) for word in desc.split()]) for desc in DescTitle_no_sw]

# create 'clean_abstract' columns
samgov_data_5yrs['Title_Description_c_sw_stm'] = desctitle_stemmed

# samgov_data_5yrs['Description_s'] = desc_stemmed
samgov_data_5yrs['Title_Description_c_sw_lem'] = desctitle_lemmatized
samgov_data_5yrs.head()
# Out:
#                                                        Title  \
# 1                            Zeiss LSM980 Microscope Upgrade
# 2                          Maestro Pro Assay System Purchase
# 6   Internet Service to the CNMI REKTS, in Saipan and Tinian
# 8                    6515--Adult Full Body Phantom w/Muscles
# 13                  7195--Mental Health Alpine Foam Mattress
#
#                  Sol#                       Department/Ind.Agency AwardNumber  \
# 1      75N95024Q00305    HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>
# 2      75N95024Q00304    HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>
# 6   1033-24-RFI-00005  UNITED STATES AGENCY FOR GLOBAL MEDIA, BBG        <NA>
# 8       36C26224Q1191             VETERANS AFFAIRS, DEPARTMENT OF        <NA>
# 13      36C25224Q0516             VETERANS AFFAIRS, DEPARTMENT OF        <NA>
#
#    AwardDate PostedDate Award$ Awardee  \
# 1        NaT 2024-05-21   <NA>    <NA>
# 2        NaT 2024-05-21   <NA>    <NA>
# 6        NaT 2024-05-21   <NA>    <NA>
# 8        NaT 2024-05-21   <NA>   null
# 13       NaT 2024-05-21   <NA>   null
#
#                                                          Link  \
# 1   https://sam.gov/opp/5417ce1082b84ea182c41aa3631aee5b/view
# 2   https://sam.gov/opp/754bb52525fe47ec981a96f85e02b2a2/view
# 6   https://sam.gov/opp/517e39ec8e504c079eea23827c1f682f/view
# 8   https://sam.gov/opp/aa602c9e662b4f53bdada251be56344c/view
# 13  https://sam.gov/opp/19282d30fd264e57881d2a784aa8fe70/view
#
#                                                                                                                                                                                                 Description  \
# 1   SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00305 Title:  Zeiss LSM980 Microscope Upgrade Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Instru...
# 2   SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00304 Title:  Maestro Pro Assay System Purchase Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Inst...
# 6   Type of Notice: Sources Sought Notice Number: 1033-24-RFI-00005 Short Description of Supply or Service: Services Place of Performance: Commonwealth of the Northern Mariana Islands (CNMI) NAICS Cod...
# 8   THIS REQUEST FOR INFORMATION (RFI)/SOURCES SOUGHT/RFI IS ISSUED SOLELY FOR INFORMATION AND PLANNING PURPOSES ONLY. THIS IS NOT A SOLICITATION. THE SUBMISSION OF PRICING, CAPABILITIES FOR PLANNING ...
# 13                                                                                                                                                        Medical foam mattresses for mental health service
#
#                                                                                                                                                                                                  Title_Desc  \
# 1   sam.gov sources sought   solicitation number:  75n95024q00305 title:  zeiss lsm980 microscope upgrade classification code:  6640 naics code:  334516 description:  analytical laboratory instrument ...
# 2   sam.gov sources sought   solicitation number:  75n95024q00304 title:  maestro pro assay system purchase classification code:  6640 naics code:  334516 description:  analytical laboratory instrumen...
# 6   type of  : sources sought   number: 1033 24 rfi 00005 short description of supply or service: services place of performance: commonwealth of the northern mariana islands (cnmi) naics code: 517810 ...
# 8   this request for information (rfi)/sources sought/rfi is issued solely for information and planning purposes only. this is not a solicitation. the submission of pricing, capabilities for planning ...
# 13                                                                                                               medical foam mattresses for mental health service 7195  mental health alpine foam mattress
#
#                                                                                                                                                                                  Title_Description_c_sw_stm  \
# 1   samgov sourc sought solicit number 75n95024q00305 titl zeiss lsm980 microscop upgrad classif code 6640 naic code 334516 descript analyt laboratori instrument manufactur sourc sought solicit propos...
# 2   samgov sourc sought solicit number 75n95024q00304 titl maestro pro assay system purchas classif code 6640 naic code 334516 descript analyt laboratori instrument manufactur sourc sought solicit pro...
# 6   type sourc sought number 1033 24 rfi 00005 short descript suppli servic servic place perform commonwealth northern mariana island cnmi naic code 517810 – telecommun psc code dg01 telecom network s...
# 8   request inform rfisourc soughtrfi issu sole inform plan purpos solicit submiss price capabl plan purpos market inform highli encourag allow rfi accord iaw far 15201e disclaim rfi issu sole inform ...
# 13                                                                                                                          medic foam mattress mental health servic 7195 mental health alpin foam mattress
#
#                                                                                                                                                                                  Title_Description_c_sw_lem
# 1   samgov source sought solicitation number 75n95024q00305 title zeiss lsm980 microscope upgrade classification code 6640 naics code 334516 description analytical laboratory instrument manufacturing ...
# 2   samgov source sought solicitation number 75n95024q00304 title maestro pro assay system purchase classification code 6640 naics code 334516 description analytical laboratory instrument manufacturin...
# 6   type source sought number 1033 24 rfi 00005 short description supply service service place performance commonwealth northern mariana island cnmi naics code 517810 – telecommunication psc code dg01...
# 8   request information rfisources soughtrfi issued solely information planning purpose solicitation submission pricing capability planning purpose market information highly encouraged allowed rfi acc...
# 13                                                                                                                      medical foam mattress mental health service 7195 mental health alpine foam mattress

# %%
# word cloud showing the frequently appearing words 
# Remove any entries that are 'nan' from the lemmatized descriptions list
desctitle_lemmatized = [item for item in desctitle_lemmatized if item != 'nan']
# Create a WordCloud object with specific configurations: black background, limit to 100 words, and set font size
wc = WordCloud(background_color='black',max_words=1000,random_state=42,max_font_size=100)
# Generate a word cloud using the combined text from the lemmatized descriptions
wc.generate(' '.join(desctitle_lemmatized))
plt.figure(figsize=(50, 7))
plt.imshow(wc)
plt.show()

# %%
# word cloud showing the words appearing the fewer times
# Join all the texts into a single string
text = ' '.join(desctitle_lemmatized)
# Count word frequencies
word_counts = Counter(text.split())
# Invert frequencies
max_freq = max(word_counts.values())
inverted_freq = {word: max_freq - freq + 1 for word, freq in word_counts.items()}
# Generate the WordCloud using inverted frequencies
wc = WordCloud(background_color='black', max_words=1000, random_state=42, max_font_size=100)
wc.generate_from_frequencies(inverted_freq)
# Plot the WordCloud
plt.figure(figsize=(15, 7))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Split the 'Title_Desc' column into lists of words and store them in a new column 'Title_Desc_lst'
samgov_data_5yrs['Title_Desc_lst']=samgov_data_5yrs['Title_Desc'].str.split(' ')
samgov_data_5yrs.head(1)
# Out:
#                              Title            Sol#  \
# 1  Zeiss LSM980 Microscope Upgrade  75N95024Q00305
#
#                       Department/Ind.Agency AwardNumber AwardDate PostedDate  \
# 1  HEALTH AND HUMAN SERVICES, DEPARTMENT OF        <NA>       NaT 2024-05-21
#
#   Award$ Awardee                                                       Link  \
# 1   <NA>    <NA>  https://sam.gov/opp/5417ce1082b84ea182c41aa3631aee5b/view
#
#                                                                                                                                                                                                Description  \
# 1  SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00305 Title:  Zeiss LSM980 Microscope Upgrade Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Instru...
#
#                                                                                                                                                                                                 Title_Desc  \
# 1  sam.gov sources sought   solicitation number:  75n95024q00305 title:  zeiss lsm980 microscope upgrade classification code:  6640 naics code:  334516 description:  analytical laboratory instrument ...
#
#                                                                                                                                                                                 Title_Description_c_sw_stm  \
# 1  samgov sourc sought solicit number 75n95024q00305 titl zeiss lsm980 microscop upgrad classif code 6640 naic code 334516 descript analyt laboratori instrument manufactur sourc sought solicit propos...
#
#                                                                                                                                                                                 Title_Description_c_sw_lem  \
# 1  samgov source sought solicitation number 75n95024q00305 title zeiss lsm980 microscope upgrade classification code 6640 naics code 334516 description analytical laboratory instrument manufacturing ...
#
#                                                                                                                                                                                             Title_Desc_lst
# 1  [sam.gov, sources, sought, , , solicitation, number:,  75n95024q00305, title: , zeiss, lsm980, microscope, upgrade, classification, code: , 6640, naics, code: , 334516, description: , analytical, ...

# %%
# Define the keywords to filter the dataframe
keywords = [" ai ",
            'artificial intelligence',
            ' iot ',
            'machine learning',
            'deep learning',
            'neural network',
            'data science',
            'cloud computing',
            "natural language processing",
            " nlp ",
            "robot",
            "robotics",
            "internet of things"]

# %%
# Function to check if text contains any of the keywords
def contains_keywords(text, keywords):
    for keyword in keywords:
        if keyword in text:
            return True
    return False

def keyword(text, keywords):
    for keywd in keywords:
        if keywd in text:
            return keywd
    return False

# Apply the function to the DataFrame
samgov_data_5yrs['Title_Desc_lower']=samgov_data_5yrs['Title_Desc'].str.lower()
samgov_data_5yrs['contains_keywords'] = samgov_data_5yrs['Title_Desc_lower'].apply(lambda x: contains_keywords(x, keywords))
samgov_data_5yrs['keyword'] = samgov_data_5yrs['Title_Desc_lower'].apply(lambda x: keyword(x, keywords))

# Filter rows that contain the keywords
filtered_df = samgov_data_5yrs[samgov_data_5yrs['contains_keywords']]
print('Total number of relevent contracts:',filtered_df.contains_keywords.sum())
# Out:
# Total number of relevent contracts: 156

# %%
# displaying the distribtuion of contracts with respect to keyword
filtered_df.groupby('keyword')['Title'].count().reset_index()
# Out:
#                        keyword  Title
# 0                          ai      25
# 1                         iot       2
# 2      artificial intelligence     19
# 3              cloud computing     10
# 4                 data science      2
# 5                deep learning      3
# 6             machine learning     11
# 7  natural language processing      1
# 8                        robot     83

# %%
# displaying the distribtuion of contracts with respect to department
filtered_df.groupby('Department/Ind.Agency')['Title'].count().reset_index()
# Out:
#                             Department/Ind.Agency  Title
# 0            AGENCY FOR INTERNATIONAL DEVELOPMENT      2
# 1                      AGRICULTURE, DEPARTMENT OF      1
# 2                         COMMERCE, DEPARTMENT OF      7
# 3                        EDUCATION, DEPARTMENT OF      1
# 4                           ENERGY, DEPARTMENT OF     20
# 5                 ENVIRONMENTAL PROTECTION AGENCY     11
# 6                 GENERAL SERVICES ADMINISTRATION      3
# 7        HEALTH AND HUMAN SERVICES, DEPARTMENT OF     16
# 8                     INTERIOR, DEPARTMENT OF THE      5
# 9                          JUSTICE, DEPARTMENT OF      4
# 10  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION     17
# 11                  NUCLEAR REGULATORY COMMISSION      1
# 12                         THE LEGISLATIVE BRANCH      2
# 13                  TRANSPORTATION, DEPARTMENT OF      2
# 14                    TREASURY, DEPARTMENT OF THE      4
# 15                VETERANS AFFAIRS, DEPARTMENT OF     60

# %%
# Display the filtered DataFrame
filtered_df[['Title','Description', 'keyword', 'contains_keywords']]
# Out:
#                                                                                                                                                                                                          Title  \
# 2                                                                                                                                                                            Maestro Pro Assay System Purchase
# 34                                                                                                                                                       99--DOI-BLM Automated Closeout Robotic Process Notice
# 523                                                                                                                                                 6515--Orthopedic Surgical Robotic Systems (VA-23-00059232)
# 828                                                                                                                                                6530--ME-ScriptPro Robot SP 200 CCC 12 SLOT CS: Tracy Heath
# 836                                                                                                                                                                                      6525-- Xenon UV Robot
# 1022                                                                                                                                                                                         Robot Stereotaxic
# 2755                                                                                                                                       (SYNOPSIS) USPSC Information Integrity and Resilience (IIR) Advisor
# 3087                                                                                                           Service/Maintenance agreement for the TOX21 & Kalypys HTS automated cell-based systems services
# 3722                                                               W065--REQUEST FOR PROPOSAL | MOBILE PET/CT RENTAL/LEASING SERVICES AT BALTIMORE LOCH RAVEN MEDICAL CENTER | ONE BASE PLUS FOUR OPTION YEARS
# 3723                                                               W065--REQUEST FOR PROPOSAL | MOBILE PET/CT RENTAL/LEASING SERVICES AT BALTIMORE LOCH RAVEN MEDICAL CENTER | ONE BASE PLUS FOUR OPTION YEARS
# 3724                                                               W065--REQUEST FOR PROPOSAL | MOBILE PET/CT RENTAL/LEASING SERVICES AT BALTIMORE LOCH RAVEN MEDICAL CENTER | ONE BASE PLUS FOUR OPTION YEARS
# 3808                                                                                            IRS Office of the Chief Procurement Officer Acquisition Support and Professional Services Request for Proposal
# 3917                                                                                                                                Rental of a Compact Robotic Prescription Dispensing System - FCI Otisville
# 3986                                                                                                                                                              B--Deep Learning & Remote Sensing Specialist
# 4057                                                                                                                                                  Z2DA--Design Build | 660-23-320 Xeriscape Campus project
# 4573                                                                                                                                                R499--Artificial Intelligence Pilot Teams (VA-24-00064764)
# 5165                                                                                                     Immersive Visualization Environment Upgrade for High Performance Computing and Visualization Research
# 5470                                                                                                                                                                      NCSER Crowdsourcing Campaign Support
# 5753                                                                                                                                                                         Requs AI Predict Floating License
# 5790                                                                                                              Notice of Intent to Sole Source_CDC_Belker Coulter Inc Service Agreement for BIomek robotics
# 6113                                                                                                                                                     Z1DA--512-23-901 Repair Exterior Granite Construction
# 6115                                                                                                                                                                        Sources Sought - Blast Booth Robot
# 6936                                                                                                                                                                          6515--SONOSITE ULTRASOUND SYSTEM
# 6949                                                                     BROAD AGENCY ANNOUNCEMENT: A Study to Determine Natural Language Processing (NLP) Capabilities with the NCCF Open Knowledge Mesh (KM)
# 7100                                                                                                                              Q521--691-24-2-208-0078-Mikroscan CMs and Software Licenses (VA-24-00056944)
# 8612                                                                                                                                                          Z2DA--554-24-106 Correct Electrical Deficiencies
# 8977                                                                                                                                               6530--ME-ScriptPro Robot SP 200 CCC 12 SLOT CS: Tracy Heath
# 9109                                                                                                                                   TECHNOLOGY TRANSFER OPPORTUNITY: Split-Ring Torque Sensor (MSC-TOPS-81)
# 9331                                                                                                                                                   Z2DA--Con (660-23-231) VMU HVAC Backup (VA-23-00089800)
# 10776                                                                                                                                       J079--NEW Base+3 Surfacide SURFcare UV Robot Service & Maintenance
# 10930                                                                                                                                       ISBEE Set Aside - Pharmacist Services Clinton Indian Health Center
# 11074                                                                                                                                        Maintenance and Repair Service for Hamilton Laboratory Equipment.
# 11370                                                                                                                                                                                 J065--New Script Pro M&R
# 11678                                                                                                                                        UPS Power and Battery Services - CSS - Competitive (SB Set Aside)
# 12333                                                                                                                                                       RFI - Cybersecurity Fraud Analytics and Monitoring
# 12452                                                                                                                                         Innovative, Visualization, Exploration and Data Analysis (IVEDA)
# 12478                                                                                                                                                         Z2DA--660-22-109 Renovate Multi-Purpose Space B8
# 12550                                                                                                                                  WEB PORTAL SUBSCRIPTION SERVICES TO SEMICONDUCTOR SUPPLY CHAIN DATABASE
# 12556                                                                                           IRS Office of the Chief Procurement Officer Acquisition Support and Professional Services Request for Proposal
# 14552                                                                                                                       3 month Rental of a M280 printer to print GRX-810 samples. (GRC) supplied powders.
# 15085                                                                                           IRS Office of the Chief Procurement Officer Acquisition Support and Professional Services Request for Proposal
# 15090                                                                                                                                                                     6515--598-25-1-784-0001 PET CT LEASE
# 15526                                                                                                                                          AHRQ Clinical Decision Support Dissemination and Infrastructure
# 15617                                                                                                                                                                Deep Learning & Remote Sensing Specialist
# 15778                                                                                                                                                                            AGILENT PMA - CrossLab Silver
# 16070                                                     3D Microscopy, Artificial Intelligence-based Quantification and Modeling for Non-Clinical Evaluation and Regulatory Support of Complex Drug Products
# 16126                                                     3D Microscopy, Artificial Intelligence-based Quantification and Modeling for Non-Clinical Evaluation and Regulatory Support of Complex Drug Products
# 16752                                                                                                                                                   Simulation and Advanced Software Services II (SASS II)
# 16963                                                                            Immersive Visualization Environment Upgrade for High Performance Computing and Visualization Research - Sources Sought Notice
# 16986                                                                            Immersive Visualization Environment Upgrade for High Performance Computing and Visualization Research - Sources Sought Notice
# 17442                                                                                                                                  WEB PORTAL SUBSCRIPTION SERVICES TO SEMICONDUCTOR SUPPLY CHAIN DATABASE
# 17473                                                                                                                                        UPS Power and Battery Services - CSS - Competitive (SB Set Aside)
# 18749                                                                                                                                                                     4460--InnoWave Unity Sonic Irrigator
# 21718                                                                                                                                        Maintenance and Repair Service for Hamilton Laboratory Equipment.
# 67742                                                                                                                                                    A--SBIR Phase II Proposal #B20P2-1F01. Early detectio
# 68014                                                                                                                                                    A--SBIR Phase I Proposal #B205C-0003.Procuring Unique
# 68563                                                                                                                         TECHNOLOGY TRANSFER OPPORTUNITY: Lunar Surface Manipulation System (LAR-TOPS-73)
# 69836                                                                                                                                                                         OASIS SB Pools 1, 3, & 4 On-Ramp
# 69837                                                                                                                                                                         OASIS SB Pools 1, 3, & 4 On-Ramp
#
#                                                                                                                                                                                                    Description  \
# 2      SAM.gov SOURCES SOUGHT NOTICE Solicitation Number:  75N95024Q00304 Title:  Maestro Pro Assay System Purchase Classification Code:  6640 NAICS Code:  334516 Description:  Analytical Laboratory Inst...
# 34     The Bureau of Land Management intends to utilize robotic process automation (RPA) to closeout contracts in accordance with FAR 4.804. The contracts to be closed all have an expired period of perfo...
# 523    Number: 36C10G24R0012 Notice Type: Combined Synopsis/Solicitation Synopsis: COMBINED SYNOPSIS/SOLICITATION This is a combined synopsis/solicitation for commercial products prepared in accordance w...
# 828                                                                                                                                                                     Robotic Prescription Dispensing System
# 836    Combined Synopsis/Solicitation Notice Combined Synopsis/Solicitation Notice Page 3 of 3 Combined Synopsis/Solicitation Notice *= Required Field Combined Synopsis/Solicitation Notice Page 1 of 3 (i...
# 1022   This is a Small Business Sources Sought notice. This is NOT a solicitation for proposals, proposal abstracts, or quotations. The purpose of this notice is to obtain information regarding: (1) the ...
# 2755   USAID intends to issue a solicitation for a Personal Services Contract (PSC) for the position Information Integrity and Resilience (IIR) Advisor, GS-14 grade equivalent, for USAID’s Bureau for Dem...
# 3087   INTRODUCTION PURSUANT TO FAR Subpart 5.2—Synopses of Proposed Contract Actions, THIS IS A PRE-SOLICITATION NOTICE OF A PROPOSED CONTRACT TO ACTION.    THIS IS A PRE-SOLICITATION NON-COMPETITIVE NO...
# 3722   STATEMENT OF WORK (SOW) PROJECT: MOBILE PET/CT SERVICES AT BALTIMORE LOCH RAVEN MEDICAL CENTER 1. Background: The Baltimore VA Medical Center (hereafter referred to as BT VAMC ) has identified a n...
# 3723   STATEMENT OF WORK (SOW) PROJECT: MOBILE PET/CT SERVICES AT BALTIMORE LOCH RAVEN MEDICAL CENTER 1. Background: The Baltimore VA Medical Center (hereafter referred to as BT VAMC ) has identified a n...
# 3724   STATEMENT OF WORK (SOW) PROJECT: MOBILE PET/CT SERVICES AT BALTIMORE LOCH RAVEN MEDICAL CENTER 1. Background: The Baltimore VA Medical Center (hereafter referred to as BT VAMC ) has identified a n...
# 3808   Amendment #00002: The purpose of this modification is to: 1. Extend the Phase I submission due date from May 22, 2024 at 3:00 pm Eastern Daylight Time to May 29, 2024 at 9:00 am Eastern Daylight T...
# 3917                                                                                                                             Rental of a Compact Robotic Prescription Dispensing System for FCI Otisville.
# 3986   This is a total small business set-aside. The U.S. Geological Survey (USGS) has a requirement for a non-personal services firm fixed price purchase order to provide deep learning and remote sensin...
# 11678   (i)        This is a combined synopsis/solicitation for commercial items prepared in accordance with the format in Subpart 12.6 as supplemented with additional information included in this notice...
# 12333  This is a Request for Information (RFI) -- hereinafter Notice. This is NOT a solicitation for proposals, proposal abstracts, request for bids or quotations, nor a promise to issue a solicitation i...
# 12452  NASA/MSFC has a requirement for NASA’s Innovative Visualization, Exploration and Data Analysis (IVEDA) that consists of differentiated competencies including Open Science alignment by adhering to ...
# 12478  THIS IS A PRESOLICIATION NOTICE A REQUEST FOR PROPOSAL TO BE POSTED ON OR ABOUT MAY 28, 2024. Renovate Multi-Purpose Space B8 (660-22-109) Salt Lake City VAMC 36C25924R0098 The Contractor/Vendor w...
# 12550  The Government is posting their response to question from vendors. In addition, combined synopsis and solictation has been revised per the response to questions. Both documents are posted as of 5-...
# 12556  Amendment #00001: The purpose of this amendment is to revise Section M. The following language “The total project price is $4.5 million dollars per year or greater” has been removed from “Factor 1...
# 14552  NASA/NSSC has a requirement for 3 month Rental of a M280 printer to print GRX-810 samples. (GRC) supplied powders.. NASA/NSSC intends to issue a sole source contract to North American Manufacturin...
# 15085  This requirement is for the establishment of a Multiple-Award Indefinite Delivery Indefinite Quantity (IDIQ) for acquisition support and professional services. This procurement is a competitive 8(...
# 15090  DISCLAIMER: THIS IS A SOURCE SOUGHT NOTICE ONLY. THIS SYNOPSIS IS NOT A REQUEST FOR QUOTE, PROPOSAL, OR BID. This notice is not a solicitation as defined by FAR 2.101, therefore it shall not be co...
# 15526  Introduction:  This is a Small Business Sources Sought notice (SBSS).  This is NOT a solicitation for proposals, proposal abstracts, or quotations.  The purpose of this notice is to obtain informa...
# 15617  This is a total small business set-aside. The U.S. Geological Survey (USGS) has a requirement for a non-personal services firm fixed price purchase order to provide deep learning and remote sensin...
# 15778  PLEASE READ THIS NOTICE CAREFULLY AS IT CONSTITUTES THE ONLY NOTICE THAT WILL BE PUBLISHED. The Federal Bureau of Investigation (FBI) intends to negotiate a sole source, firm-fixed-price contract ...
# 16070  This is a combined synopsis/solicitation for commercial services prepared in accordance with the Federal Acquisition Regulation (FAR) format in 15.204-1, as supplemented with additional informatio...
# 16126  This is a combined synopsis/solicitation for commercial services prepared in accordance with the Federal Acquisition Regulation (FAR) format in 15.204-1, as supplemented with additional informatio...
# 16752  Background  The National Aeronautics and Space Administration (NASA)/ Lyndon B. Johnson Space Center (JSC) is hereby requesting information from potential sources for the Simulation and Advanced S...
# 16963  THIS IS A COMBINED SYNOPSIS/SOLICITATION FOR COMMERCIAL ITEMS PREPARED IN ACCORDANCE WITH THE FORMAT IN FAR SUBPART 12.6-STREAMLINED PROCEDURES FOR EVALUATION AND SOLICITATION FOR COMMERCIAL ITEMS...
# 16986  THIS IS A COMBINED SYNOPSIS/SOLICITATION FOR COMMERCIAL ITEMS PREPARED IN ACCORDANCE WITH THE FORMAT IN FAR SUBPART 12.6-STREAMLINED PROCEDURES FOR EVALUATION AND SOLICITATION FOR COMMERCIAL ITEMS...
# 17442  In 2022, President Joe Biden signed into law the CHIPS and Science Act of 2022, which provides the Department of Commerce (DOC) with $50 billion for programs to support semiconductor research, dev...
# 17473   (i)        This is a combined synopsis/solicitation for commercial items prepared in accordance with the format in Subpart 12.6 as supplemented with additional information included in this notice...
# 18749  Attachment 1: Template for Combined Synopsis-Solicitation for Commercial Products and Commercial Services Effective Date: 03/15/2023 Revision: 01 Page 8 of 8 Description This is a combined synopsi...
# 21718  (i) This is a combined synopsis/solicitation for commercial services prepared in accordance with the format in Subpart 12.6 as supplemented with additional information included in this notice. Thi...
# 22765  PLEASE READ THIS NOTICE CAREFULLY AS IT CONSTITUTES THE ONLY NOTICE THAT WILL BE PUBLISHED. The Federal Bureau of Investigation (FBI) intends to negotiate a sole source, firm-fixed-price contract ...
# 22776  Request for Quotations 5G/6G Core Networks and Algorithms Support Services RFQ No. NIST-RFQ-24-6701710 This is a Combined Synopsis / Solicitation for Commercial Items prepared in accordance with t...
# 23267  Update – May 1, 2024 NASA has selected 9 companies to conduct studies of commercial services at Mars for the study RFP. A summary of the awardees and further details can be found using the links b...
# 24037  FERMILAB REQUESTS YOUR FIRM FIXED PRICE QUOTE FOR THE FOLLOWING: 1 EACH:  CLEAN ROOM ROBOTIC ARM PER SPECIFICATIONS BELOW: Technical Specifications - The robotic arm shall meet or exceed the requi...
# 24490  This is a source sought synopsis only. The purpose of this synopsis is to gain knowledge of potential qualified sources and their size classification (hubzone, 8(a), small, small disadvantage, sma...
# 24599  The Department of the Interior, Interior Business Center, Acquisition Services Directorate intends to utilize robotic process automation (RPA) to closeout contracts in accordance with FAR 4.804. T...
# 25079  Metrohm Titrosampler Purchase and install a Metrohm 855 Robotic Titrosampler Basic 1T/1P with water bath and autosampler. New titrator will be coupled with a water bath and autosampler to expand o...
# 25186  Metrohm Titrosampler Purchase and install a Metrohm 855 Robotic Titrosampler Basic 1T/1P with water bath and autosampler. New titrator will be coupled with a water bath and autosampler to expand o...
# 27261  ***** This is a REQUEST FOR INTEREST ONLY! This request does not constitute a request for proposal, request for quote, or invitation for bid. The intent of this request is to identify potential of...
# 27509  NOTICE OF INTENT to Sole Source SOLICITATION NUMBER:  75N95024Q00237 TITLE: Service/Maintenance Agreement for the Microwaves, V-10s, and Isolera Systems CLASSIFICATION CODE: J066- Maintenance/Repa...
# 28280  NASA’s Technology Transfer Program solicits inquiries from companies interested in obtaining license rights to commercialize, manufacture and market the following technology. License rights may be...
# 28605  This requirement is for the planned life-cycle replacement of the PackBot 510 series robot 510 series robot. This Packbot 525 upgrade will include significant technological upgrade and includes di...
# 28637  This requirement is for the planned life-cycle replacement of the PackBot 510 series robot 510 series robot. This Packbot 525 upgrade will include significant technological upgrade and includes di...
# 28682  Notice of Intent 24-007534 Product Service Code: 6515 NAICS Code:  339112 - (Not Small Business Size Standards- 1,250 Average Number of Employees) Place of Performance: Bethesda, MD 20892 USA PSC-...
# 29157                                                                                                                                                                                                     <NA>
# 29449  Novel Exoskeleton Controllers Design & Development and Advanced Rehabilitation Robot for RTT Use and Research at Center for Limb Loss and MoBility (CLiMB) of Rehabilitation Research & Development ...
# ...
# 52084  Request for Information Data and Analytics Integrated Modernization and Operations (DAIMO) VA-24-00013843 Introduction This Request for Information (RFI) is for planning purposes only and shall no...
# 52226  INTRODUCTION: In accordance with Federal Acquisition Regulation (FAR) 10.002(b)(2), this Sources Sought Notice is for market research and information purposes only at this time and shall not be co...
# 53060  INTRODUCTION: In accordance with Federal Acquisition Regulation (FAR) 10.002(b)(2), this Sources Sought Notice is for market research and information purposes only at this time and shall not be co...
# 53446  TECHNOLOGY LICENSING OPPORTUNITY Intelligent Lifecycle Management for Battery Energy Storage: Transitioning from First Life to Second Life and Materials Recycling An advanced technical approach to...
# 54096  NASA’s Technology Transfer Program solicits inquiries from companies interested in obtaining license rights to commercialize, manufacture and market the following technology. License rights may be...
# 54142  NASA’s Technology Transfer Program solicits inquiries from companies interested in obtaining license rights to commercialize, manufacture and market the following technology. License rights may be...
# 54179  NASA’s Technology Transfer Program solicits inquiries from companies interested in obtaining license rights to commercialize, manufacture and market the following technology. License rights may be...
# 54868  Modification 8- August 31, 2023 This is Modification 8 to the synopsis entitled Neutral Buoyancy Laboratory (NBL) Operations Contract II (NOC II) Sources Sought Synopsis/Request for Information (R...
# 55185  Solicitation No. 75N95023Q00627 Title: PCR Workstation (No Thermocycler) (Automated Liquid Handler/pipetting robot) i.  This is a combined synopsis/solicitation for commercial items prepared in ac...
# 55694  Modification 8- August 31, 2023 This is Modification 8 to the synopsis entitled Neutral Buoyancy Laboratory (NBL) Operations Contract II (NOC II) Sources Sought Synopsis/Request for Information (R...
# 55999  Notice of Proposed Contract Action (NOPCA). THIS IS NOT A REQUEST FOR COMPETITIVE PROPOSALS. This is a notice of intent to award BPA Call Order with the Enterprise Global Navigation Satellite Syst...
# 56389  Modification 7- August 17, 2023 This is Modification 7 to the synopsis entitled Neutral Buoyancy Laboratory (NBL) Operations Contract II (NOC II) Sources Sought Synopsis/Request for Information (R...
# 56809  **PLEASE REFERENCE "RFP 746072 AMENDMENT 3" IN PROPOSAL SUBMITTAL EMAIL SUBJECT LINE Battelle Pacific Northwest Division, as operator of Pacific Northwest National Laboratory (PNNL), manages the E...
# 56810  **PLEASE REFERENCE "RFP 746072 AMENDMENT 3" IN PROPOSAL SUBMITTAL EMAIL SUBJECT LINE Battelle Pacific Northwest Division, as operator of Pacific Northwest National Laboratory (PNNL), manages the E...
# 58385  **PLEASE REFERENCE "RFP 746072 AMENDMENT 2" IN PROPOSAL SUBMITTAL EMAIL SUBJECT LINE Battelle Pacific Northwest Division, as operator of Pacific Northwest National Laboratory (PNNL), manages the E...
# 59116  Battelle Pacific Northwest Division, as operator of Pacific Northwest National Laboratory (PNNL), manages the Environmental Molecular Sciences Laboratory (EMSL) for the Department of Energy. This ...
# 59162  SOFTWARE LICENSING OPPORTUNITY FieldSim - Maximize Agricultural Machine Efficiency with Advanced Simulation Modeling  Leverage FieldSim, a cutting-edge agricultural simulation model, to optimize f...
# 59926  Battelle Pacific Northwest Division, as operator of Pacific Northwest National Laboratory (PNNL), manages the Environmental Molecular Sciences Laboratory (EMSL) for the Department of Energy. This ...
# 60351  NASA Langley Research Center (LaRC) is hereby soliciting information from potential partners to participate in a proposal development activity that will design, develop, build, and ground demonstr...
# 60471  NASA Langley Research Center (LaRC) is hereby soliciting information from potential partners to participate in a proposal development activity that will design, develop, build, and ground demonstr...
# 62610  Request for Information (RFI) Instructions  RFI No. 2022-10-07-MARTIN  Design, Build, Integrate and Deliver an Automated Platform for Soil Extractions and Analyses  Battelle Contact Information:  ...
# 62669  Request for Information (RFI) Instructions  RFI No. 2022-10-07-MARTIN  Design, Build, Integrate and Deliver an Automated Platform for Soil Extractions and Analyses  Battelle Contact Information:  ...
# 62682                                                                                         EPA SBIR FY22-23 Phase II - Machine-learning-assisted development of PCB-free alternatives to commodity pigments
# 62683                                       EPA SBIR FY22-23 Phase II - Robotic, Artificial intelligence (AI) Powered Trash System for Facility Sorting and Auditing Waste and Educating Transient Populations
# 62690                                                                                                                                      EPA SBIR FY22-23 Phase II - Zero Waste Management Platform using AI
# 62778  Request for Information (RFI) Instructions  RFI No. 2022-10-07-MARTIN  Design, Build, Integrate and Deliver an Automated Platform for Soil Extractions and Analyses  Battelle Contact Information:  ...
# 62779  Request for Information (RFI) Instructions  RFI No. 2022-10-07-MARTIN  Design, Build, Integrate and Deliver an Automated Platform for Soil Extractions and Analyses  Battelle Contact Information:  ...
# 63540  Noncompetitive GSA Federal Supply Schedule (FSS) Order to procure secure data center space for NRC HQ’s secure cloud computing and cloud access with ‘zero-hop’ connectivity services available loca...
# 65870  This notice is a combined synopsis/solicitation for commercial items prepared in accordance with the format in FAR Subpart 12.6, as supplemented with additional information included in this notice...
# 67742                                SBIR Phase II Proposal #B20P2-1F01. Early detection and prediction of harmful algal blooms using low cost, networked IOT sensors and machine learning. AquaRealTime, Inc.
# 68014                                           SBIR Phase I Proposal #B205C-0003.Procuring Unique MHSM Fuels for Electricity Generation and Cooking with Machine Learning QC Assessment. Farm to Flame Energy
# 68563  NASA’s Technology Transfer Program solicits inquiries from companies interested in obtaining license rights to commercialize, manufacture and market the following technology. License rights may be...
# 69836  OASIS SB Pool 4 Awardees and Apparent Successful Offerors List In accordance with OASIS SB Pools 1, 3, & 4 On-Ramp Solicitation number GS00Q13DR0002P1P3P4 Section M.2.(c), the Government anticipat...
# 69837  OASIS SB Pool 3 Awardees and Apparent Successful Offerors List In accordance with OASIS SB Pools 1, 3, & 4 On-Ramp Solicitation number GS00Q13DR0002P1P3P4 Section M.2.(c), the Government anticipat...
#
#                            keyword  contains_keywords
# 2                     data science               True
# 34                           robot               True
# 523                          robot               True
# 828                          robot               True
# 836                          robot               True
# 1022                         robot               True
# 2755       artificial intelligence               True
# 3087                         robot               True
# 3722                           ai                True
# 3723                           ai                True
# 3724                           ai                True
# 3808                         robot               True
# 3917                         robot               True
# 3986                 deep learning               True
# 4057               cloud computing               True
# 4573                           ai                True
# 5165              machine learning               True
# 5470              machine learning               True
# 5753                           ai                True
# 5790                         robot               True
# 6113               cloud computing               True
# 6115                         robot               True
# 6936                          iot                True
# 6949                           ai                True
# 7100                         robot               True
# 8612               cloud computing               True
# 8977                         robot               True
# 9109                         robot               True
# 9331               cloud computing               True
# 10776                        robot               True
# 10930                        robot               True
# 11074                        robot               True
# 11370                        robot               True
# 11678                        robot               True
# 12333             machine learning               True
# 12452      artificial intelligence               True
# 12478              cloud computing               True
# 12550      artificial intelligence               True
# 12556                        robot               True
# 14552                          ai                True
# 15085                        robot               True
# 15090                deep learning               True
# 15526              cloud computing               True
# 15617                deep learning               True
# 15778                        robot               True
# 16070      artificial intelligence               True
# 16126      artificial intelligence               True
# 16752                        robot               True
# 16963             machine learning               True
# 16986             machine learning               True
# 17442      artificial intelligence               True
# 17473                        robot               True
# 18749                        robot               True
# 21718                        robot               True
# 22765                        robot               True
# 22776                          ai                True
# 23267                        robot               True
# 24037                        robot               True
# 24490                        robot               True
# 24599                        robot               True
# 25079                        robot               True
# 25186                        robot               True
# 27261                        robot               True
# 27509                        robot               True
# 28280                        robot               True
# 28605                        robot               True
# 28637                        robot               True
# 28682                        robot               True
# 29157                        robot               True
# 29449                        robot               True
# 30337                        robot               True
# 30461                        robot               True
# 30496                        robot               True
# 32209                        robot               True
# 32759                        robot               True
# 33789      artificial intelligence               True
# 33983                        robot               True
# 34925                          ai                True
# 36573                          ai                True
# 37238                        robot               True
# 37659                        robot               True
# 37660                        robot               True
# 39065                        robot               True
# 39403                        robot               True
# 40131                          ai                True
# 40141                          ai                True
# 40711                        robot               True
# 41134                          ai                True
# 41221                        robot               True
# 41446              cloud computing               True
# 41479             machine learning               True
# 41489                          ai                True
# 41492                          ai                True
# 41661                        robot               True
# 41928      artificial intelligence               True
# 42109                        robot               True
# 42331      artificial intelligence               True
# 42332                          ai                True
# 42801                          ai                True
# 43497      artificial intelligence               True
# 43815                        robot               True
# 44098             machine learning               True
# 44551                        robot               True
# 44951                          ai                True
# 45811  natural language processing               True
# 46179                          ai                True
# 46616                          ai                True
# 46617                          ai                True
# 47376                        robot               True
# 48313              cloud computing               True
# 48430                        robot               True
# 48495              cloud computing               True
# 49417                        robot               True
# 49583                        robot               True
# 50457                          ai                True
# 51200                        robot               True
# 51608                        robot               True
# 51764      artificial intelligence               True
# 51893      artificial intelligence               True
# 51904             machine learning               True
# 51908      artificial intelligence               True
# 51916      artificial intelligence               True
# 52084      artificial intelligence               True
# 52226                        robot               True
# 53060                        robot               True
# 53446             machine learning               True
# 54096                        robot               True
# 54142                        robot               True
# 54179                        robot               True
# 54868      artificial intelligence               True
# 55185                        robot               True
# 55694      artificial intelligence               True
# 55999                        robot               True
# 56389      artificial intelligence               True
# 56809                        robot               True
# 56810                        robot               True
# 58385                        robot               True
# 59116                        robot               True
# 59162                        robot               True
# 59926                        robot               True
# 60351                        robot               True
# 60471                        robot               True
# 62610                        robot               True
# 62669                        robot               True
# 62682             machine learning               True
# 62683      artificial intelligence               True
# 62690                          ai                True
# 62778                        robot               True
# 62779                        robot               True
# 63540              cloud computing               True
# 65870                 data science               True
# 67742                         iot                True
# 68014             machine learning               True
# 68563                        robot               True
# 69836                          ai                True
# 69837                          ai                True

# %%
# saving the dataframe to csv
filtered_df.to_csv("AI_contracts.csv", index=True)
