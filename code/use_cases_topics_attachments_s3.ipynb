# %% [markdown]
# ### Notebook for extracting the summaries and topics from the attacments available on the website [sam.gov](https://sam.gov/:).
# ### Files needed to run the notebook:
#     -- 'AI_contracts.csv'
#     -- Downloaded attachments (pdf and word files)
# ### Files generated from the notebook:
#     -- 'text_attachments.json'
#     -- 'ai_use_case_topics_attachments.csv'

# %%
# Department dictionary to create deprtment codes
dept_dict={'VETERANS AFFAIRS, DEPARTMENT OF': 'VA',
 'ENERGY, DEPARTMENT OF': 'DOE',
 'NATIONAL AERONAUTICS AND SPACE ADMINISTRATION': 'NASA',
 'HEALTH AND HUMAN SERVICES, DEPARTMENT OF': 'HHS',
 'ENVIRONMENTAL PROTECTION AGENCY': 'EPA',
 'COMMERCE, DEPARTMENT OF': 'DOC',
 'INTERIOR, DEPARTMENT OF THE': 'DOI',
 'TREASURY, DEPARTMENT OF THE': 'TREAS',
 'JUSTICE, DEPARTMENT OF': 'DOJ',
 'GENERAL SERVICES ADMINISTRATION': 'GSA',
 'AGENCY FOR INTERNATIONAL DEVELOPMENT':'USAID',
 'THE LEGISLATIVE BRANCH': 'TLB',
 'TRANSPORTATION, DEPARTMENT OF': 'DOT',
 'EDUCATION, DEPARTMENT OF': 'DOE',
 'AGRICULTURE, DEPARTMENT OF': 'USDA',
 'NUCLEAR REGULATORY COMMISSION': 'NRC'}

# %%
# Read the AI_contracts file  
import pandas as pd
df_AI_contracts=pd.read_csv('AI_contracts.csv', index_col='Unnamed: 0')
df_AI_contracts=df_AI_contracts[['Title', 'Sol#', 'Department/Ind.Agency', 'AwardNumber', 'AwardDate', 'PostedDate', 'Award$', 'Awardee', 'Link', 'Description']]
df_AI_contracts[ 'Department_code']=df_AI_contracts[ 'Department/Ind.Agency'].map(dept_dict)
df_AI_contracts.head()

# %%
import os
from PyPDF2 import PdfReader
import json
from docx import Document
import pandas as pd

# Function to extract text from the pdf file
def extract_text_from_pdf(pdf_path):
    text_list = []
    with open(pdf_path, 'rb') as file:
        reader = PdfReader(file)
        num_pages = len(reader.pages)
        for page_num in range(num_pages):
            page = reader.pages[page_num]
            text = page.extract_text()
            text_list.append(text)
    return text_list

# Function to extract text from the word file
def extract_text_from_word(word_path):
    text_list = []
    doc = Document(word_path)
    for paragraph in doc.paragraphs:
        text_list.append(paragraph.text)
    return text_list

# Function to iterate over pdf files to extract text and save to a dict
def read_pdfs_in_folder(pdf_folder_path, data):
    for filename in os.listdir(pdf_folder_path):
        if filename.endswith('.pdf'):
            file_path = os.path.join(pdf_folder_path, filename)
            text_list = extract_text_from_pdf(file_path)
            data[filename] = text_list
# Function to iterate over word files to extract text and save to a dict
def read_words_in_folder(word_folder_path, data):
    for filename in os.listdir(word_folder_path):
        if filename.endswith('.docx'):
            file_path = os.path.join(word_folder_path, filename)
            text_list = extract_text_from_word(file_path)
            data[filename] = text_list

def read_files_in_folders(pdf_folder_path, word_folder_path, output_json_path):
    data = {}
    read_pdfs_in_folder(pdf_folder_path, data)
    read_words_in_folder(word_folder_path, data)
    
    with open(output_json_path, 'w') as json_file:
        json.dump(data, json_file, indent=4)


current_working_directory = os.getcwd()
pdf_folder_path = os.path.join(current_working_directory, "docs", "pdfs")
word_folder_path = os.path.join(current_working_directory, "docs", "word")
output_json_path = 'text_attachments.json'

# Read files and save the extracted text to the JSON file
read_files_in_folders(pdf_folder_path, word_folder_path, output_json_path)
print(f"Extracted text from files saved to {output_json_path}")

# %%
import json
import pandas as pd

# create a datframe from .json file
def create_dataframe_from_json(json_path):
    with open(json_path, 'r') as json_file:
        data = json.load(json_file)
    df = pd.DataFrame(list(data.items()), columns=['Filename', 'Text'])
    return df

json_path='text_attachments.json'
df_AI_contracts_attach = create_dataframe_from_json('text_attachments.json')
df_AI_contracts_attach['no_pages']=df_AI_contracts_attach['Text'].apply(len)
df_AI_contracts_attach.head()
# Out:
#                                             Filename  \
# 0  1.JL-2672-110923Combined_1.29.24-compressed-v1...
# 1  1.JL-2672-110923RFP_noMsnDes-1.29.24-compresse...
# 2           10.1MarsHandbook2022-2040-compressed.pdf
# 3           2022.10.28RFI-2022-10-07-MartinQandA.pdf
# 4   36C25724Q0141A00002-CANCELATIONOFREQUIREMENT.pdf
#
#                                                 Text  no_pages
# 0  [ \nJet Propulsion Laboratory  \nCalifornia In...       496
# 1  [ \nJet Propulsion Laboratory  \nCalifornia In...        47
# 2  [© 2023 California Institute of Technology  \n...       449
# 3  [ \n \n  \nTel:  (509) 372- 4071  \nLaurie.Mar...         1
# 4  [ \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n...         2

# %%
# Preprocessing the extracted text from attachments using NLTK library
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

def preprocess_text(text):
    tokens = word_tokenize(text)
    tokens = [word.lower() for word in tokens]
    tokens = [word for word in tokens if word.isalpha()]
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    preprocessed_text = ' '.join(tokens)
    return preprocessed_text

df_AI_contracts_attach['Text_proc_lst']=df_AI_contracts_attach['Text'].apply(lambda lst:  [preprocess_text(ele) for ele in lst])

# %%
pd.set_option('display.max_colwidth', 100)
df_AI_contracts_attach.head()
# Out:
#                                                         Filename  \
# 0  1.JL-2672-110923Combined_1.29.24-compressed-v10-and-later.pdf
# 1            1.JL-2672-110923RFP_noMsnDes-1.29.24-compressed.pdf
# 2                       10.1MarsHandbook2022-2040-compressed.pdf
# 3                       2022.10.28RFI-2022-10-07-MartinQandA.pdf
# 4               36C25724Q0141A00002-CANCELATIONOFREQUIREMENT.pdf
#
#                                                                                                   Text  \
# 0  [ \nJet Propulsion Laboratory  \nCalifornia Institute of Technology  \n4800 Oak Grove Drive  \nP...
# 1  [ \nJet Propulsion Laboratory  \nCalifornia Institute of Technology  \n4800 Oak Grove Drive  \nP...
# 2  [© 2023 California Institute of Technology  \nGovernment Support Acknowledged  MARS MISSION  \nD...
# 3  [ \n \n  \nTel:  (509) 372- 4071  \nLaurie.Martin@p nnl.gov   \nOctober 28, 2022 RFI-2022-10- 07...
# 4  [ \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n   \n  \n  \n  \n...
#
#    no_pages  \
# 0       496
# 1        47
# 2       449
# 3         1
# 4         2
#
#                                                                                          Text_proc_lst
# 0  [jet propulsion laboratory california institute technology oak grove drive pasadena ca date janu...
# 1  [jet propulsion laboratory california institute technology oak grove drive pasadena ca date janu...
# 2  [california institute technology government support acknowledged mars mission design handbook je...
# 3  [tel p october artin design build integrate deliver automated platform soil extractions analyses...
# 4  [project number applicable code administered number code issued name address contractor req numb...

# %%
# df_AI_contracts_attach.Text_proc_lst.iloc[0]
#df_AI_contracts_attach.Text.iloc[100]

# %%
# keywords to check in the extracted text
elements_to_check = ['Scope of Work', 'SOW', 'Statement of Objectives', 'Performance Work Statement', 'PWS', 'Scope Work', 'Statement Objectives', 'Statement of Objective','STATEMENT OF WORK', 'STATEMENT WORK']

# %%
# Function to check keywords in the extracted text
def check_presence(lst,elements_to_check):
    idxs=[]
    elements_to_check = [ele.lower() for ele in elements_to_check]
    for idx, txt_strng in enumerate(lst):
        for element in elements_to_check:
            if element in txt_strng:
                # print(idx, txt_strng)
                idxs.append(idx)
    return idxs

# %%
# Applying the function to extract indices of the pdf pages
pd.set_option('display.max_rows', 100)
df_AI_contracts_attach['Text_proc_lst_index']=df_AI_contracts_attach['Text_proc_lst'].apply(lambda x: check_presence(x, elements_to_check))

# %%
import itertools
def extract_elements(row):
    final_text=[]
    elements = row['Text_proc_lst']
    indices = row['Text_proc_lst_index']
    for i in indices:
        final_text.append(elements[i:i+5])
    flattened_list = list(itertools.chain.from_iterable(final_text))
    unique_elements = set(flattened_list)
    unique_elements_list = list(unique_elements)
    return ' '.join(unique_elements_list)

# Apply the function to each row
df_AI_contracts_attach['relevant_text_pages_preproc'] = df_AI_contracts_attach.apply(extract_elements, axis=1)

# %%
import itertools
def extract_elements(row):
    final_text=[]
    elements = row['Text']
    indices = row['Text_proc_lst_index']
    for i in indices:
        final_text.append(elements[i:i+5])
    flattened_list = list(itertools.chain.from_iterable(final_text))
    unique_elements = set(flattened_list)
    unique_elements_list = list(unique_elements)
    return ' '.join(unique_elements_list)

# Apply the function to each row
# df_AI_contracts_attach['extracted_elements'] = df_AI_contracts_attach.apply(extract_elements, axis=1)
df_AI_contracts_attach['relevant_text_pages_No_preproc'] = df_AI_contracts_attach.apply(extract_elements, axis=1)

# %%
df_AI_contracts_attach_final = df_AI_contracts_attach[df_AI_contracts_attach['relevant_text_pages_preproc']!=''].copy()

# %%
df_AI_contracts_attach_final.drop(['Text_proc_lst', 'Text_proc_lst_index'], axis=1, inplace=True)

# %%
df_AI_contracts_attach_final
# Out:
#                                                                                                 Filename  \
# 0                                          1.JL-2672-110923Combined_1.29.24-compressed-v10-and-later.pdf
# 1                                                    1.JL-2672-110923RFP_noMsnDes-1.29.24-compressed.pdf
# 2                                                               10.1MarsHandbook2022-2040-compressed.pdf
# 5                                                                          6.1_BattellePNNLRFP746072.pdf
# 6                                                                      6.2_BattellePNNLRFP746072_SOW.pdf
# 8                                                              6.4_BattellePNNLRFP746072_Hazard_Form.pdf
# 9                                                                 80JSC022R0004NOIS2RFPforOn-Ramping.pdf
# 20                     ATTACHMENTB-CONTRACTADMINISTRATION-BNOE-NXEQORTHOPEDICSURGICALROBOTICSSYSTEMS.pdf
# 23                                                                       AttachmentC-StatementofWork.pdf
# 32                                                                BattellePNNLRFP746072Am2_Questions.pdf
# 33                                                  BattellePNNLRFP746072Amendment1-Question.Answers.pdf
# 34                                                                   BattellePNNLRFP746072Amendment1.pdf
# 35                                                               BattellePNNLRFP746072Amendment1_SOW.pdf
# 36                                                                   BattellePNNLRFP746072Amendment2.pdf
# 37                                                                   BattellePNNLRFP746072Amendment3.pdf
# 39                                                                                    CFAMPWS(DRAFT).pdf
# 53                                                                 D_SOWHamiltonMaintenanceandRepair.pdf
# 56                                                                                FDA-75F40124Q00047.pdf
# 59                          FinalCombinedSynopsisandSolicitation-WebPortal-1333ND24QNB480212-5-10-24.pdf
# 61                                                            GovernmentResponsetoQuestions_05102024.pdf
# 64           II_01_Attachment01_SectionM.EvaluationFactorsforAward.FunctionalCategory1(Optimization).pdf
# 65    II_01_Attachment01_SectionM.EvaluationFactorsforAward.FunctionalCategory1(Optimization)5.10.24.pdf
# 66   II_01_Attachment02_SectionM.EvaluationFactorsforAward.FunctionalCategory2(AcquisitionLifecyclePl...
# 67   II_01_Attachment02_SectionM.EvaluationFactorsforAward.FunctionalCategory2(AcquisitionLifecyclePl...
# 68                     II_01_Attachment03_SectionM.EvaluationFactorsforAward.FunctionalCategory3(IT).pdf
# 69              II_01_Attachment03_SectionM.EvaluationFactorsforAward.FunctionalCategory3(IT)5.10.24.pdf
# 72                        II_01_Attachment07_RelevantExperienceVerification_Amendment000025.17.24(1).pdf
# 73                                                 II_01_Attachment07_ReleventExperienceVerification.pdf
# 76                                                                       II_01_RFP_2032H8-24-R-00005.pdf
# 77                                                          II_01_RFP_2032H8-24-R-00005P000025.17.24.pdf
# 78                                 II_01_RFP_2032H8-R-24-00005GovernmentResponsestoQuestionsPart1(1).pdf
# 79                                                                         IndustryDayQuestions_Set1.pdf
# 80                                                                         IndustryDayQuestions_Set2.pdf
# 81                                                LimitedSourcesJustificationforZero-HopConnectivity.pdf
# 82                                                                                           NOCDRDs.pdf
# 83                                                                 NOCIIdRFPCommentDispositions_set1.pdf
# 84                                                                 NOCIIdRFPCommentDispositions_Set2.pdf
# 87                                                                                            NOCSOW.pdf
# 93                                                                                RFI_DraftPWS_DAIMO.pdf
# 94                                                                RFQ246-24-Q-0112PHARMACISTSERVICES.pdf
# 96                                                                             SATPC0034982Tab044SOW.pdf
# 114                                            Solicitation_GS00Q-13-DR-0002_OASIS_SB_P1P3P4_On-Ramp.pdf
# 115                                   Solicitation_GS00Q-13-DR-0002_OASIS_SB_P1P3P4_On-Ramp_-_Amd_02.pdf
# 116                                   Solicitation_GS00Q-13-DR-0002_OASIS_SB_P1P3P4_On-Ramp_-_Amd_05.pdf
# 117                                   Solicitation_GS00Q-13-DR-0002_OASIS_SB_P1P3P4_On-Ramp_-_Amd_06.pdf
# 118                                                                                Sol_140G0124Q0140.pdf
# 121                                                            SOW-WebPortalSupplyChain-5-7-24-FINAL.pdf
# 122                                                                                    SOWPHARMACIST.pdf
# 123                                                                             SSN75N91024SS6811966.pdf
# 125                                                                                   36C10B24Q0048.docx
# 126                                                                                   36C10B24Q0072.docx
# 127                                                                                   36C10B24Q0232.docx
# 128                                                                                   36C10B24Q0267.docx
# 129                                                                                   36C10B24Q0429.docx
# 132                                                                                 36C24524Q0527_1.docx
# 134                                                                                   36C24E24Q0058.docx
# 139                                                                                 36C25224Q0439_3.docx
# 140                                                                                   36C25624Q0884.docx
# 141                                                                                   36C25724Q0141.docx
# 142                                                                                 36C25724Q0141_1.docx
# 143                                                                           36C25724Q0141_23Jan24.docx
# 144                                                                                   36C25724Q0628.docx
# 149                                                                                   36C26024Q0556.docx
# 151                                                                                   36C26124Q0438.docx
# 152                                                                                 36C26124Q0438_1.docx
# 157                                                                                 36C26224Q1188_1.docx
# 160                                                               ATTACHMENT1-QASP-UROLOGYPHYSICIAN.docx
# 163                                                       Attachment_1-_Performance_Work_Statement_.docx
# 164                                                                                           B6SOW.docx
# 166                                                                                    CSS5GSupport.docx
# 167                                                                               D1StatementofWork.docx
# 168                                                                         DCSS-CRFQ75N95024R00079.docx
# 170                                                                     DraftNOCIISourcesSought_RFI.docx
# 171                                                                                   DRAFTNOCIISOW.docx
# 172                                                                           DRAFTPWSClimateChange.docx
# 173                                                                          ESDRe-competePWSforRFI.docx
# 174                                                                    FSCITOperationsSupportRFIPWS.docx
# 177                        OnsiteBoardCertified_RoboticsTrained_OperativeUrologyPhysicianPWS-6Dec23.docx
# 179                                                                     PWS-AIprototypes-RFIDraftv2.docx
# 180                                                                            PWS5G_6GSupportFinal.docx
# 181                                                            RequestforProposalNCSERCrowdsourcing.docx
# 193                   SECTION_J.16._ATT._(16)_OASIS_FSSCTA_Performance_Verification_Letter_-_Amd_04.docx
# 194                       SECTION_J.16_Attachment_(16)_OASIS_FSSCTA_Performance_Verification_Letter.docx
# 204                                                                                 StatementofWork.docx
# 206                                                                          VendorCapabilityMatrix.docx
#
#                                                                                                     Text  \
# 0    [ \nJet Propulsion Laboratory  \nCalifornia Institute of Technology  \n4800 Oak Grove Drive  \nP...
# 1    [ \nJet Propulsion Laboratory  \nCalifornia Institute of Technology  \n4800 Oak Grove Drive  \nP...
# 2    [© 2023 California Institute of Technology  \nGovernment Support Acknowledged  MARS MISSION  \nD...
# 5    [ \nPage 1 of 26  \n \nBattelle Memorial Institute, Pacific Northwest Division  \nActing Under P...
# 6    [Battelle Pacific Northwest Division  \nas operator of Pacific Northwest National Laboratory (PN...
# 8    [Battelle  PNNL RFP 746072 \nHazard Form  \nPage 1 of 1 \n \nAttention Bidder! Anticipated hazar...
# 9    [NASA Open Innovation Services 2 (NOIS2) On -Ramping \n80JSC022R0004   \nPage 1 of 74 \n  \n  \n...
# 20   [Page 1 of 18 \n SECTION B – CONTRACT  ADMINISTRATION / INVOICE INSTRUCTIONS  \nB.1 CONTRACT ADM...
# 23   [STATEMENT OF WORK  \n3D Microscopy, Artificial Intelligence -based Quantification, and Modeling...
# 32   [Batelle PNNL RFP 746072 Amendment 2  \nQues�ons/Answers /Clariﬁca�ons  \nJune 26, 202 3 \n \nPa...
# 33   [PNNL RFP 746072 Amendment  1 \nQuestions/Clarifications  & Answers \nJune 8, 2023 \nPlease see ...
# 34   [ \nPage 1 of 26  \n \nBattelle Memorial Institute, Pacific Northwest Division \nActing Under Pr...
# 35   [Battelle Pacific Northwest Division \nas operator of Pacific Northwest National Laboratory (PNN...
# 36   [ \nPage 1 of 26  \n \nBattelle Memorial Institute, Pacific Northwest Division  \nActing Under P...
# 37   [ \nPage 1 of 26  \n \nBattelle Memorial Institute, Pacific Northwest Division  \nActing Under P...
# 39   [ \n1  Performance Work Statement  \n \nIRS CYBERSECURTY  FRAUD  ANALYTICS  AND MONITORING  \n \...
# 53   [ \nFAR Part 11—Describing Agency Needs \nPage 1 of 3 \n STATEMENT OF WORK  \n \nGENERAL INFORMA...
# 56   [ \n \n \n \n \n \n \n \nSolicitation No: 75F40124Q00047 \nCenter  for Devices  and Radiological...
# 59   [ \nPage 1 of 20  \n WEB PORTAL SUBSCRIPTION SERVICES TO SEMICONDUCTOR SUPPLY CHAIN DATABASE  \n...
# 61   [Government Response to Questions -1333ND24QNB130212:  \n \n Solicitation Section  Questions  Re...
# 64   [Attachment # 01 - Section M - Functional Category 1 (FC1) – Optimization   \nPage 1 of 7 \n Sec...
# 65   [Attachment # 01 - Section M - Functional Category 1 (FC1) – Optimization   \nPage 1 of 7 \n Sec...
# 66   [Attachment # 02 - Section M - Functional Category 2 (FC2) - Acquisition Planning and Support \n...
# 67   [Attachment # 02 - Section M - Functional Category 2 (FC2) - Acquisition Planning and Support \n...
# 68   [Attachment # 03 - Section M - Functional Category 3 (FC 3) - Information Technology (IT)  \nPag...
# 69   [Attachment # 03 - Section M - Functional Category 3 (FC 3) - Information Technology (IT)  \nPag...
# 72   [Source  Selection  Information  – See FAR 2.101  and 3.104  1 OF 2 \nDescribe  the scope  of wo...
# 73   [Solicitation 2032H8 -24-R-00005   \n  ATTACHMENT# 07  \n \nSource Selection Information – See F...
# 76   [SOLICITA\nTION, \nOFFER AND AWARD\n 4. TYPE OF SOLICITATION 2. \nCONTRACT NUMBER 3. SOLICITATIO...
# 77   [AMENDMENT OF SOLICITATION/MODIFICATION OF CONTRACT 11. CONTRACT ID CODE I PAfE FF \n1101PAGES \...
# 78   [#Document \nReferencePage/Paragraph/  \nClause Reference Question Government Response\n1 II_01_...
# 79   [NBL Operations Contract II (NOC II)  \nIndustry Day Questions and Answers – Set 1  \nMarch 29 ,...
# 80   [NBL Operations Contract II (NOC II)  \nIndustry Day Questions and Answers – Set 2 \n March 29 -...
# 81   [June 21, 2022\nMEMORANDUM TO: Domonique Malone, Contracting Officer, ADM/AMD/OBA \nFROM:  Matth...
# 82   [ATTACHMENT J-10\nDATA REQUIREMENTS SHEETS\nDRD-NOC-01 (Page 1 of 2), ATTACHMENT J-10\nDATA REQU...
# 83   [Solicitation Number: 80JSC023R0007  \nProcurement Title: Neutral Buoyancy Laboratory (NBL) Oper...
# 84   [Solicitation Number: 80JSC023R0007  \nProcurement Title: Neutral Buoyancy Laboratory (NBL) Oper...
# 87   [Neutral Buoyancy Laboratory (N BL) Operations Contract (NOC) \nSection C: Statement of Work  (S...
# 93   [  \n \n    \nPERFORMANCE WORK STATEMENT (PWS)  \nDEPARTMENT OF VETERANS AFFAIRS \nOffice of Inf...
# 94   [ \n \nCombined Synopsis/Solicitation  RFQ # 246-24-Q-0112 \n   \n \n  Page 1 of  3  \n  \n \nTh...
# 96   [NASA Statement of Work – Printer rental  \n05/03/2024  \n1.0 Scope of Work  \nThe vendor  shall...
# 114  [OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-D...
# 115  [OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-D...
# 116  [OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-D...
# 117  [OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-D...
# 118  [SEE ADDENDUM IS CHECKEDCODE 18a. PAYMENT WILL BE MADE BY\nCODE FACILITY CODE \n17b. CHECK IF RE...
# 121  [ \nPage 1 of 3 \n WEB PORTAL SUBSCRIPTION SERVICES TO SEMICONDUCTOR SUPPLY CHAIN \nDATABASE 133...
# 122  [Department of Health and Human Services\nIndian Health Service\nClinton Indian Health Center\n1...
# 123  [GENERAL INFORMATION/CLASSIFICATION  \nTitle:  Brand Name or Equal: Attana automated sample -rob...
# 125  [, , GENERAL INFORMATION, CONTACT INFORMATION, ADDITIONAL INFORMATION, , DESCRIPTION, , Request ...
# 126  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, Reque...
# 127  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, Reque...
# 128  [, , GENERAL INFORMATION, CONTACT INFORMATION, ADDITIONAL INFORMATION, , DESCRIPTION, Request fo...
# 129  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, Depar...
# 132  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, STATE...
# 134  [, , GENERAL INFORMATION, , , , Novel Exoskeleton Controllers Design & Development and Advanced ...
# 139  [, SECTION B - CONTINUATION OF SF 1449 BLOCKS, \t, B.1  CONTRACT ADMINISTRATION DATA  (continuat...
# 140  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, DISCL...
# 141  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, See a...
# 142  [, , GENERAL INFORMATION, CONTACT INFORMATION, ADDITIONAL INFORMATION, , DESCRIPTION, The Depart...
# 143  [, SECTION B - CONTINUATION OF SF 1449 BLOCKS, B.1 CONTRACT ADMINISTRATION DATA,   1.  Contract ...
# 144  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, This ...
# 149  [, SECTION B - CONTINUATION OF SF 1449 BLOCKS, B.1  CONTRACT ADMINISTRATION DATA,   1.  Contract...
# 151  [DISCLAIMER,   This RFI is issued solely for information and planning purposes only and does not...
# 152  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, DISCL...
# 157  [, , GENERAL INFORMATION, , PLACE OF PERFORMANCE, , ADDITIONAL INFORMATION, , DESCRIPTION, , Sta...
# 160  [The contractor will be evaluated in accordance with the following:, PURPOSE, This Quality Assur...
# 163  [, Performance Work Statement, Introduction and Background, 1. Introduction, Effective decision ...
# 164  [STATEMENT OF WORK, (SOW), , GENERAL INFORMATION, Acquisition of service/maintenance agreement f...
# 166  [Request for Quotations\n5G/6G Core Networks and Algorithms Support Services\nRFQ No. NIST-RFQ-2...
# 167  [STATEMENT OF WORK (SERVICES), (SOW), , , GENERAL INFORMATION, UPS Power and Battery Services, ,...
# 168  [COMPETITIVE , COMBINED SYNOPSIS / SOLICITATION, , Title: UPS Power and Battery Services (Brand-...
# 170  [Neutral Buoyancy Laboratory (NBL) Operations Contract II (NOC II) Sources Sought Synopsis/Reque...
# 171  [Neutral Buoyancy Laboratory (NBL) Operations Contract II (NOCII), , Statement of Work (SOW), , ...
# 172  [Performance Work Statement\nPublic Health National Program Office , Patient Care Services, Depa...
# 173  [, PERFORMANCE WORK STATEMENT (PWS), DEPARTMENT OF VETERANS AFFAIRS, Office of Information & Tec...
# 174  [, PERFORMANCE WORK STATEMENT (PWS), DEPARTMENT OF VETERANS AFFAIRS, FINANCIAL SERVICES CENTER (...
# 177  [SCHEDULE OF SERVICES, The Contractor shall furnish all key personnel to provide services necess...
# 179  [, , , , , , , , , , , , PERFORMANCE WORK STATEMENT (PWS), DEPARTMENT OF VETERANS AFFAIRS, , VA ...
# 180  [PERFORMANCE WORK STATEMENT, 5G/6G Core Networks and Algorithms Support Services\n, BACKGROUND I...
# 181  [REQUEST FOR PROPOSAL, , NCSER Crowdsourcing Campaign Support, , May 16, 2024, General Informati...
# 193  [Federal Supply Schedule (FSS) Contractor Team Arrangement (CTA) , MEMBER VERIFICATION LETTER, ,...
# 194  [Federal Supply Schedule (FSS) Contractor Team Arrangement (CTA) , MEMBER VERIFICATION LETTER, ,...
# 204  [STATEMENT OF WORK, , Title, Novel Exoskeleton Controllers Design & Development and Advanced Reh...
# 206  [ Vendor Capability Matrix, Mark an X in the right column next to all Sections of the NOC SOW th...
#
#      no_pages  \
# 0         496
# 1          47
# 2         449
# 5          26
# 6          19
# 8           1
# 9          74
# 20         18
# 23         12
# 32          3
# 33          3
# 34         26
# 35         21
# 36         26
# 37         26
# 39         47
# 53          3
# 56         48
# 59         20
# 61          3
# 64          7
# 65          7
# 66          7
# 67          7
# 68          8
# 69          8
# 72          2
# 73          2
# 76        100
# 77        101
# 78         17
# 79         15
# 80          6
# 81          4
# 82         91
# 83          5
# 84          2
# 87         31
# 93         97
# 94          3
# 96          2
# 114       120
# 115       120
# 116       127
# 117       127
# 118        33
# 121         3
# 122         5
# 123         3
# 125        59
# 126        76
# 127        68
# 128        63
# 129        63
# 132       254
# 134        11
# 139      1285
# 140       320
# 141        46
# 142        25
# 143      1364
# 144       307
# 149       709
# 151       214
# 152       221
# 157       170
# 160        73
# 163        43
# 164        67
# 166        61
# 167       111
# 168       136
# 170       156
# 171       846
# 172       164
# 173       765
# 174      1737
# 177       271
# 179       699
# 180        62
# 181       121
# 193        50
# 194        53
# 204       146
# 206         3
#
#                                                                              relevant_text_pages_preproc  \
# 0     mars program office mars mission design handbook novembe r jpl release signature page prepared ...
# 1    rfp jl january programmatic considerations discuss whether proposed service sufficiently mature ...
# 2    mars program office mars mission design handbook novembe r jpl release page figure minimum assoc...
# 5    request proposal number page attachment rfp following detailed sections provided informational p...
# 6    battelle pnnl rfp statement work april page reserved references attachments scheduling workflow ...
# 8    battelle pnnl rfp hazard form page attention bidder anticipated hazards identified work based st...
# 9    nasa open innovation services page accordance far part organizational consultant conflicts inter...
# 20   page comprom ised information considers relevant respect unsecured protected health information ...
# 23   contract develop conduct three correlative imaging quantitative image analysis cqas image silico...
# 32   batelle pnnl rfp amendment june page pnnl response scope limited producing microsolv vials ready...
# 33   pnnl rfp amendment answers june please see answers questions submitted response referenced rfp q...
# 34   request proposal number amendment page rights reserved battelle may reject proposals request cla...
# 35   battelle pnnl rfp statement work april page sample must fit within single c ontainer spli tting ...
# 36   request proposal number amendment page applicable export control classification number eccn inte...
# 37   request proposal number amendment page misses discovery deficiency procedure plan system real po...
# 39   capability provided leveraging contract delivery tasks identified specifically fraud analytics s...
# 53   far part agency needs page statement work general information title project maintenance repair s...
# 56   microscopy artificial intelligence quantification modeling non clinical evaluation regulatory su...
# 59   page web portal subscription services semiconductor supply chain database section introduction c...
# 61   goa l able dynamically search cross reference output semiconductor criteria multiple sources bui...
# 64   attachment section functional category optimization page appropriate government may choose perfo...
# 65   attachment section functional category optimization page appropriate government may choose perfo...
# 66   attachment section functional category acquisition planning support services page pro ject defin...
# 67   attachment section functional category acquisition planning support services page project define...
# 68   attachment section functional category fc information technology page evaluate proposed hourly r...
# 69   attachment section functional category fc information technology page best practices ensuring em...
# 72   source selection information see far describe scope work tasks performed deliverables received s...
# 73   solicitation attachment source selection information see far signature contracting officer contr...
# 76   ordering procedures task orders asps must solicited awarded co authority award contracts interna...
# 77   automation task pws para optimization contractor shall support full range procurement organizati...
# 78   rfp oral presentation slide formatthis section states slide limit page provides example minute p...
# 79   key attributes looking program manager see answer q uestion key attributes looking contractor ev...
# 80   high bay west wall buildout responsible completing contract offered prime ii contrac tor center ...
# 81   certifications certify justification proposed acquisition reviewed best knowledge belief informa...
# 82    attachment data requirements sheets page drd title dat e curr ent ver drl line item training ce...
# 83   attachments l must consistent attachment submitted volume attachment l submitted volume iii gove...
# 84   solicitation number procurement title neutral buoyancy laboratory nbl operations contract ii noc...
# 87   neutral buoyancy laboratory n bl operations contract noc section c statement work sow contract a...
# 93   data analytics integrated modernization operations daimo data systems development modernization ...
# 94   combined rfq page combined commercial products commercial services prepared accordance format fe...
# 96    nasa statement work printer rental scope work vendor shall deliver additively manufactured bloc...
# 114  oasis small business solicitation pools solicitation amendment page section reference descriptio...
# 115  oasis small business solicitation pools solicitation amendment page section reference descriptio...
# 116  oasis small business solicitation pools solicitation amendment page task orders minimum maximum ...
# 117  oasis small business solicitation pools solicitation amendment page services provided oasis sb s...
# 118  page telephone number email address line address line address line e contracting officer may des...
# 121  page web portal subscription services semiconductor supply chain database supply chain mapped mi...
# 122  department health human services indian health service clinton indian health center reporting re...
# 123  general title brand name equal attana automated sample attana cell system notice type sources so...
# 125   interested vendors shall minimum provide following information initial paragraph submission des...
# 126   draft pws provided sufficient detail describe technical requirements encompass software develop...
# 127   provide rough order magnitude rom including estimated quantities unit pricing additional antici...
# 128   yes answer question c responses due later est march via email sarah kuna contract specialist da...
# 129  government requests industry review provide commentary attached draft performance work statement...
# 132   due increased emphasis privacy information security following special contract requirements est...
# 134   notice intent sole source regional procurement office east region rpo east office research deve...
# 139  va directive va cybersecurity program directives handbooks va series related va information incl...
# 140  west street  place performance mobile pet ct lease performance work statement purpose john mccle...
# 141   central texas veterans healthcare system onsite operative urology physician services see attach...
# 142   va anticipates issuing small business requirement solicitation available download home interest...
# 143  clinical personnel required contractor shall provide contractor physician competent qualified pe...
# 144                       maintenance repair automated pharmacy robotic dispensing system statement work
# 149  price requirement statement work technical compliance statement work contractor shall provide al...
# 151   department veterans affairs period performance date award one year performance work statement p...
# 152   department veterans affairs period performance date award one year performance work statement p...
# 157   scope contractor shall provide necessary labor materials supplies parts software needed general...
# 160   verification documentation provided contractor review pws method surveillance selected define d...
# 163  effective decision support systems help natural resource managers make better decisions face mas...
# 164   scope work agreement following systems coverage statement work personnel must trained authorize...
# 166   price evaluation criteria basis award addendum far past performance price quotations shall subm...
# 167   scope work quarterly preventative maintenance repair emergency service parts ups systems ncats ...
# 168  far contract terms conditions required implement statutes executive products commercial services...
# 170   pertinent contract information current contract follows additional documents would like see noc...
# 171   contractor shall ensure external customers utilize nbl without compromising safety process inte...
# 172   department veterans affairs performance work statement public health national program office pa...
# 173   contents contractor shall serve one vendors mvsp environment provide services contractor shall ...
# 174   tasks pws shall performed va facilities specifically va fsc facilities located main fsc office ...
# 177  clinical personnel required contractor shall provide contractor physician competent qualified pe...
# 179   contractor shall ensure adequate data information system security accordance va standard operat...
# 180   background information core networks algorithms support services optimal resource allocation qo...
# 181   business proposal also includes conflict interest plan page limit price information must submit...
# 193  complete copy task call including statement work  documents attached verified cognizant governme...
# 194  complete copy task call including statement work  documents attached verified cognizant governme...
# 204   statement work title background novel exoskeleton controllers design development advanced rehab...
# 206                                 mark x right column next sections noc sow apply company capabilities
#
#                                                                           relevant_text_pages_No_preproc
# 0     RFP No.: JL -2672-110923  \nJanuary 2 9,2024 \n2 1.3 Programmatic Considerations  \n \n1.3.1 Di...
# 1    RFP No. JL -2672 -110923  \nExhibit V, XV  \nFlight Software:  Software specifically design ed t...
# 2    Mars Program Office   Mars Mission Design Handbook (2022 -2040) \nNovembe r 6, 202 3  JPL D -106...
# 5    Request for Proposal  Number: 746072  \nPage 14 of 26 o Personnel actions resulting in a change ...
# 6    Battelle  PNNL RFP 746072 \nStatement of Work  \nApril 11, 2023 \nPage 8 of 19 rotating or gentl...
# 8    Battelle  PNNL RFP 746072 \nHazard Form  \nPage 1 of 1 \n \nAttention Bidder! Anticipated hazard...
# 9    NASA Open Innovation Services 2 (NOIS2) On -Ramping \n80JSC022R0004   \nPage 29 of 74 \n  \n SEC...
# 20   Page 16 of 18 \n  \n (2) Description of the event, including: \n \n (a) date of occurrence;  \n ...
# 23    \n 8. Statement of Work  \nThis statement of work (SOW) is to conduct three dimensional (3D) co...
# 32   Batelle PNNL RFP 746072 Amendment 2  \nQues�ons/Answers /Clariﬁca�ons \nJune 26, 202 3 \n \nPage...
# 33   PNNL RFP 746072 Amendment  1 \nQuestions  & Answers \nJune 8, 2023 \nPage 3 of 3 \n17. Confirm w...
# 34   Request for Proposal Number: 746072 Amendment 1 \nPage 9 of 26 shall provide written, electronic...
# 35   Battelle PNNL RFP 746072 \nStatement of Work \nApril 11June 8 , 2023 \nPage 20 of 21 o Include d...
# 36   Request for Proposal  Number: 746072  Amendment 2 \nPage 21 of 26 Deep Freezer  \n • Enough stor...
# 37   Request for Proposal  Number: 746072 Amendment 3 \nPage 20 of 26 • Large enough work envelope \n...
# 39    \n42  performance  management; this analysis  yields  information  that indicates  whether \nex...
# 53    \nFAR Part 11—Describing Agency Needs \nPage 1 of 3 \n STATEMENT OF WORK  \n \nGENERAL INFORMAT...
# 56   3D Microscopy, Artificial Intelligence -based Quantification, and Modeling for Non - \nClinical ...
# 59    \nPage 1 of 20  \n WEB PORTAL SUBSCRIPTION SERVICES TO SEMICONDUCTOR SUPPLY CHAIN DATABASE  \n1...
# 61   TO OFFERORS – \nCOMMERCIAL ITEMS  \n(Reference FAR \n12.301(b)(1)): Due Date for \nQuotations  w...
# 64   Attachment # 01 - Section M - Functional Category 1 (FC1) – Optimization   \nPage 6 of 7 \n and ...
# 65   Attachment # 01 - Section M - Functional Category 1 (FC1) – Optimization   \nPage 6 of 7 \n and ...
# 66   Attachment # 02 - Section M - Functional Category 2 (FC2) - Acquisition Planning and Support \nS...
# 67   Attachment # 02 - Section M - Functional Category 2 (FC2) - Acquisition Planning and Support \nS...
# 68   Attachment # 03 - Section M - Functional Category 3 (FC 3) - Information Technology (IT)  \nPage...
# 69   Attachment # 03 - Section M - Functional Category 3 (FC 3) - Information Technology (IT)  \nPage...
# 72   Solicitation  2032H8 -24-R-00005  \nATTACHMENT#  07 \nSource  Selection  Information  – See FAR ...
# 73   Solicitation 2032H8 -24-R-00005   \n  ATTACHMENT# 07  \n \nSource Selection Information – See FA...
# 76   renting economy cars, stayi ng at hotels only at the Government per diem rate (if the Government...
# 77   at (866) 973 -3131. Once a contract award has been made, the contractor will be contacted by the...
# 78   13 RFP Page 89, Schedule Can the government provide a more detailed schedule for Phase II Propos...
# 79    \n64.  Does the LMF have the capacity to provide \nwhat is needed to support NOCII? \n The majo...
# 80    ISS (e.g., AMS ) and new mockups to support Artemis \nCampaign Programs.  \n127.  What is the a...
# 81   provide NRC HQ, Regional and field sites wide area network (WAN) connectivity and \naccess to mu...
# 82    ATTACHMENT J-10\nDATA REQUIREMENTS SHEETS\nDRD-NOC-22 (Page 2 of 5)f. Submission:\nTechnical Me...
# 83   capacity. The Government \nanticipates this may remain \nthe case for much or all of the \nNOCII...
# 84   Solicitation Number: 80JSC023R0007  \nProcurement Title: Neutral Buoyancy Laboratory (NBL) Opera...
# 87   Neutral Buoyancy Laboratory (N BL) Operations Contract (NOC)\nSection C: Statement of Work  (SOW...
# 93   Data and Analytics Integrated Modernization and Operations (DAIMO)  \nData -centric Systems Deve...
# 94    \n \nCombined Synopsis/Solicitation  RFQ # 246-24-Q-0112 \n   \n \n  Page 1 of  3  \n  \n \nThi...
# 96   NASA Statement of Work – Printer rental  \n05/03/2024  \n1.0 Scope of Work  \nThe vendor  shall ...
# 114  OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-DR...
# 115  OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-DR...
# 116  OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-DR...
# 117  OASIS SMALL BUSINESS SOLICITATION  \nON-RAMP (POOLS 1, 3, & 4)  \n SOLICITATION NO. GS00Q -13-DR...
# 118  Page 22whether affiliation exists, consideration is given to all appropriate factors including c...
# 121   \nPage 2 of 3 \n WEB PORTAL SUBSCRIPTION SERVICES TO SEMICONDUCTOR SUPPLY CHAIN \nDATABASE 1333...
# 122  Department of Health and Human Services\nIndian Health Service\nClinton Indian Health Center\n1S...
# 123  Item Product Description  Product No.  Quantity  \n1 Attana upgrade: automated sample-robot for ...
# 125  There is a page limitation for this RFI of fifteen (15) pages.  The Government will not review a...
# 126   Are there alternative solutions to the existing requirements that could better meet the VA’s ne...
# 127   There is a page limitation for this RFI of 25 pages.  The Government will not review any other ...
# 128   If “NO”, please provide your comments/recommendations on elements of the draft PWS that may con...
# 129   Please also provide any questions or comments you may have on the Draft PWS.  Please provide yo...
# 132      a.  Privacy Training:  Contractor and their sub-contractors assigned work under the contract...
# 134  No solicitation package will be issued for this requirement. This is not a request for competiti...
# 139    (h) Bio-Medical devices and other equipment or systems. Bio-Medical devices and other equipmen...
# 140        Little Rock, AR 72205  2. Place of Performance:        4300 West 7th Street  Performance W...
# 141   See attached document: Onsite Board Certified_Robotics Trained_Operative Urology Physician PWS ...
# 142   The North American Industry Classification System (NAICS) Code is 561320 (Temporary Help Servic...
# 143   C.1 52.212-4 CONTRACT TERMS AND CONDITIONS—COMMERCIAL PRODUCTS AND COMMERCIAL SERVICES (NOV 202...
# 144             \t STATEMENT OF WORK AUTOMATED PHARMACY ROBOTIC DISPENSING SYSTEM MAINTENANCE AND REPAIR
# 149  *Adherence to the technical characteristics and meeting the special standard is more important t...
# 151   A draft Performance Work Statement (PWS) is attached to this notice. Performance Work Statement...
# 152   A draft Performance Work Statement (PWS) is attached to this notice. See attached document: DRA...
# 157   Period of Performance:  Statement of Work Scope: The Contractor shall provide all necessary lab...
# 160   SAMPLE QASP PERFORMANCE REPORT        DATE: __________________ VERIFICATION AND/OR DOCUMENTATIO...
# 163  The first task of this SOW is to assist in the development of an automated machine learning pipe...
# 164   Acquisition of service/maintenance agreement for TOX21 & Kalypys HTS automated cell-based syste...
# 166   D.       Price  Contract Number  \nVolume 2: Price Quotation and Small Business Subcontracting ...
# 167   Perform operational inspection of unit to confirm proper operation in all modes: Independently ...
# 168  Addendum to FAR 52.212-4 Contract Terms and Conditions—Commercial Products and Commercial Servic...
# 170   The pertinent contract information for the current contract is as follows: Interested parties w...
# 171   SMP – Software Management Plan a. \tThe Contractor shall electronically maintain accurate and c...
# 172   Department of Veterans Affairs  Performance Work Statement\nPublic Health National Program Offi...
# 173   4.2.1\tON-SITE ACCESS FOR GOVERNMENT PERSONNEL\t10 PERFORMANCE DETAILS Improve IT customer serv...
# 174   d.  Pegaworld Conference: one time per year for two people for five days per trip. Pegaworld co...
# 177   Place of Performance: Contractor shall furnish services at the Oline E. Teague Medical Center, ...
# 179   Example user outcomes are as follows:  VA may provide remote access to VA specific systems/netw...
# 180   Optimal resource allocation for E2E quality-of-service (QoS) assurance over 5G/6G networks.  Th...
# 181   The business proposal, which also includes the Conflict of Interest Plan, has no page limit.  P...
# 193  Provide invoices or other evidence to support the dollar value of the work your company performe...
# 194  Provide invoices or other evidence to support the dollar value of the work your company performe...
# 204   Novel Exoskeleton Controllers Design & Development and Advanced Rehabilitation Robot for RTT Us...
# 206   Mark an X in the right column next to all Sections of the NOC SOW that apply for your company’s...

# %%
import ollama
def gen_summaries_llama3(text: str):
    response = ollama.chat(model='llama3', messages=[
        {"role" : "system", "content" : "You are a Summary generator. Generate a summary from the provided text."},
        {"role" : "user", "content" : "Convert the following text into a summary of the form 'Summary: <summary>':"},
        {"role" : "user",  "content" : text}
    ])
    title = response['message']['content']
    return title

# %%
# Apply the LLAMA summarizer funtion on the preprocessed text
df_AI_contracts_attach_final['Summary_No_preproc'] = df_AI_contracts_attach_final['relevant_text_pages_No_preproc'].apply(lambda x: gen_summaries_llama3(x))

# %%
# Apply the LLAMA summarizer funtion on the text without preprocessing
df_AI_contracts_attach_final['Summary_preproc'] = df_AI_contracts_attach_final['relevant_text_pages_preproc'].apply(lambda x: gen_summaries_llama3(x))

# %%
import ollama

def gen_topic_llama3(text: str):
    response = ollama.chat(model='llama3', messages=[
        {"role" : "system", "content" : "You are a topic labeller, I want you to identiy the topic for given text from the list of topics given below?, note just give me the topic name and limit your answer to two tokens"},
        {"role" : "user", "content" : """
                                        Topics:
                                    	1.	Accessibility: using AI for translation / interpretation, section 508 compliance, plain language, or other activities to increase accessibility of documents and interactions with the government
	                                    2.	Policy-making and public engagement: use of AI in any stage of developing regulations or gathering input
                                        3.	Asset management: use of AI to manage both physical and digital assets
                                        4.	Hotlines and service desks: use of AI to triage, respond, and refer to calls, texts, emails
                                        5.	Service / benefits access: use of AI to support determining eligibility for services, streamlining applications, etc.
                                        6.	Program integrity: use of AI to detect potential fraud or other wrong-doing in use of public benefits and services
                                        7.	Case management: use of AI to document and summarize interactions, suggest and enable referrals
                                        8.	Service delivery: use of AI to provide direct services either to the public or to state/local/tribal/territorial governments 
                                        9.	People operations: use of AI for purposes related to recruiting, retaining, and off-boarding employees
                                        10.	Internal operations: administrative use cases for AI, e.g. notetaking, virtual assistants
                                        11.	Other
                                    Identify the topic the text belongs to '<topic_name>':"""},
        {"role" : "user",  "content" : text}
    ])
    Topic = response['message']['content']
    return Topic

# %%
# Apply the LLAMA topic labelling funtion on the preprocessed text
df_AI_contracts_attach_final['topics_preproc']=df_AI_contracts_attach_final['relevant_text_pages_preproc'].apply(lambda x:  gen_topic_llama3(x))

# %%
# Apply the LLAMA topic labelling funtion on the text without preprocessing
df_AI_contracts_attach_final['topics_no_preproc']=df_AI_contracts_attach_final['relevant_text_pages_No_preproc'].apply(lambda x:  gen_topic_llama3(x))

# %%
# save the summaries and topics to csv file
df_AI_contracts_attach_final.to_csv("ai_use_case_topics_attachments.csv")
